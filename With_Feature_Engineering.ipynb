# %% [markdown]
# We shall add 3 new features:
# * Frequency of Gene
# * Frequency of Variation
# * No of words in Text

# %% [markdown]
# <p style="font-size:36px;text-align:center"> <b>Personalized cancer diagnosis</b> </p>

# %% [markdown]
# <h1>1. Business Problem</h1>

# %% [markdown]
# <h2>1.1. Description</h2>

# %% [markdown]
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/ </p>
#
# *   List item
# *   List item
#
#
# <p> Data: Memorial Sloan Kettering Cancer Center (MSKCC)</p>
# <p> Download training_variants.zip and training_text.zip from Kaggle.</p>
#
# <h6> Context:</h6>
# <p> Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/discussion/35336#198462</p>
#
# <h6> Problem statement : </h6>
# <p> Classify the given genetic variations/mutations based on evidence from text-based clinical literature. </p>

# %% [markdown]
# <h2>1.2. Source/Useful Links</h2>

# %% [markdown]
#  Some articles and reference blogs about the problem statement

# %% [markdown]
# 1. https://www.forbes.com/sites/matthewherper/2017/06/03/a-new-cancer-drug-helped-almost-everyone-who-took-it-almost-heres-what-it-teaches-us/#2a44ee2f6b25
# 2. https://www.youtube.com/watch?v=UwbuW7oK8rk
# 3. https://www.youtube.com/watch?v=qxXRKVompI8

# %% [markdown]
# <h2>1.3. Real-world/Business objectives and constraints.</h2>

# %% [markdown]
# * No low-latency requirement.
# * Interpretability is important.
# * Errors can be very costly.
# * Probability of a data-point belonging to each class is needed.

# %% [markdown]
# <h1>2. Machine Learning Problem Formulation</h1>

# %% [markdown]
# <h2>2.1. Data</h2>

# %% [markdown]
# <h3>2.1.1. Data Overview</h3>

# %% [markdown]
# - Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment/data
# - We have two data files: one conatins the information about the genetic mutations and the other contains the clinical evidence (text) that  human experts/pathologists use to classify the genetic mutations.
# - Both these data files are have a common column called ID
# - <p>
#     Data file's information:
#     <ul>
#         <li>
#         training_variants (ID , Gene, Variations, Class)
#         </li>
#         <li>
#         training_text (ID, Text)
#         </li>
#     </ul>
# </p>

# %% [markdown]
# <h3>2.1.2. Example Data Point</h3>

# %% [markdown]
# <h6>training_variants</h6>
# <hr>
# ID,Gene,Variation,Class<br>
# 0,FAM58A,Truncating Mutations,1 <br>
# 1,CBL,W802*,2 <br>
# 2,CBL,Q249E,2 <br>
# ...
#
# <h6> training_text</h6>
# <hr>
# ID,Text <br>
# 0||Cyclin-dependent kinases (CDKs) regulate a variety of fundamental cellular processes. CDK10 stands out as one of the last orphan CDKs for which no activating cyclin has been identified and no kinase activity revealed. Previous work has shown that CDK10 silencing increases ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2)-driven activation of the MAPK pathway, which confers tamoxifen resistance to breast cancer cells. The precise mechanisms by which CDK10 modulates ETS2 activity, and more generally the functions of CDK10, remain elusive. Here we demonstrate that CDK10 is a cyclin-dependent kinase by identifying cyclin M as an activating cyclin. Cyclin M, an orphan cyclin, is the product of FAM58A, whose mutations cause STAR syndrome, a human developmental anomaly whose features include toe syndactyly, telecanthus, and anogenital and renal malformations. We show that STAR syndrome-associated cyclin M mutants are unable to interact with CDK10. Cyclin M silencing phenocopies CDK10 silencing in increasing c-Raf and in conferring tamoxifen resistance to breast cancer cells. CDK10/cyclin M phosphorylates ETS2 in vitro, and in cells it positively controls ETS2 degradation by the proteasome. ETS2 protein levels are increased in cells derived from a STAR patient, and this increase is attributable to decreased cyclin M levels. Altogether, our results reveal an additional regulatory mechanism for ETS2, which plays key roles in cancer and development. They also shed light on the molecular mechanisms underlying STAR syndrome.Cyclin-dependent kinases (CDKs) play a pivotal role in the control of a number of fundamental cellular processes (1). The human genome contains 21 genes encoding proteins that can be considered as members of the CDK family owing to their sequence similarity with bona fide CDKs, those known to be activated by cyclins (2). Although discovered almost 20 y ago (3, 4), CDK10 remains one of the two CDKs without an identified cyclin partner. This knowledge gap has largely impeded the exploration of its biological functions. CDK10 can act as a positive cell cycle regulator in some cells (5, 6) or as a tumor suppressor in others (7, 8). CDK10 interacts with the ETS2 (v-ets erythroblastosis virus E26 oncogene homolog 2) transcription factor and inhibits its transcriptional activity through an unknown mechanism (9). CDK10 knockdown derepresses ETS2, which increases the expression of the c-Raf protein kinase, activates the MAPK pathway, and induces resistance of MCF7 cells to tamoxifen (6). ...

# %% [markdown]
# <h2>2.2. Mapping the real-world problem to an ML problem</h2>

# %% [markdown]
# <h3>2.2.1. Type of Machine Learning Problem</h3>

# %% [markdown]
# <p>
#
#             There are nine different classes a genetic mutation can be classified into => Multi class classification problem
#
#
#
# </p>

# %% [markdown]
# <h3>2.2.2. Performance Metric</h3>

# %% [markdown]
# Source: https://www.kaggle.com/c/msk-redefining-cancer-treatment#evaluation
#
# Metric(s):
# * Multi class log-loss
# * Confusion matrix

# %% [markdown]
# <h3>2.2.3. Machine Learing Objectives and Constraints</h3>

# %% [markdown]
# <p> Objective: Predict the probability of each data-point belonging to each of the nine classes.
# </p>
# <p> Constraints:
# </p>
# * Interpretability
# * Class probabilities are needed.
# * Penalize the errors in class probabilites => Metric is Log-loss.
# * No Latency constraints.

# %% [markdown]
# <h2>2.3. Train, CV and Test Datasets</h2>

# %% [markdown]
#  Split the dataset randomly into three parts train, cross validation and test with 64%,16%, 20% of data respectively

# %% [markdown]
# <h1>3. Exploratory Data Analysis</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import SGDClassifier
from imblearn.over_sampling import SMOTE
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier
warnings.filterwarnings("ignore")

from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#!wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kagglesdsdata/competitions/6841/44307/training_variants.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1618224928&Signature=QKXiia8c0QVWmyHkQB%2F75yDoQAFit2%2Ff5CCYqKsd5B982BMBGuHT7uKqP%2FucMeK1Lfv7%2BRyhuOtsTjT0U3xANlFKe%2FhkhrrRirv7sZ8M8O2H9IIJ138p5IxT2riCTe2jqXlrXlqurGikKt%2BzGO6Wt2MhhtrAtiX63nEicy4A4ts0fkUWyGS9Gvmy5h8AkeHLq7NLAnZ7KCmqMCI8JAwzfgJDBek8e1ruFT0DlJja9PQgSi5Byn2du5AWcW%2BTd5u%2F9i%2FZoObJfN%2F5xwxpzphj0bMqs3i2pG%2BRbgV5UpSCbjBaBo3OtWGxyWbV9lm%2FFGSRgOUZnag1vDpVCl9a4fx%2BrQ%3D%3D&response-content-disposition=attachment%3B+filename%3Dtraining_variants.zip" -c -O 'training_variants.zip'

# %%
#!wget --header="Host: storage.googleapis.com" --header="User-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.114 Safari/537.36" --header="Accept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9" --header="Accept-Language: en-US,en;q=0.9" --header="Referer: https://www.kaggle.com/" "https://storage.googleapis.com/kagglesdsdata/competitions/6841/44307/training_text.zip?GoogleAccessId=web-data@kaggle-161607.iam.gserviceaccount.com&Expires=1618224963&Signature=NiROKonG1Zj515DuyRmvZlj%2BttKOkmc1fefeldOOZnH7Wm2wkBuUmiaOkg61un6X91J%2FG6x63ikQT%2BCaeT0wnuWbQA7lHTnt6gRxOSjJzxDIy05mh8xVv9YLb6o6BHRstyQfJHYHbxAkwas9nHnpeZVaB9MILkYsRdO48BvZ4iThhihTr1BZZLMMTy290bVVpq%2BLf%2FlT191RK14VW2jVVIBN2Q1G49%2FIPpTWgYFnPxLH9r1hrK5bnnBVXKjPKCeIxgOLr8dObskBoITMVVSrU3yzrWu9lG8uLdj%2FkYICnzWf3si2%2BkLKIByT7NTyZTfJUaEEzq4HTYan16zVZU1Yxw%3D%3D&response-content-disposition=attachment%3B+filename%3Dtraining_text.zip" -c -O 'training_text.zip'

# %%
#!unzip training_text.zip

# %%
#!unzip training_variants.zip

# %% [markdown]
# <h2>3.1. Reading Data</h2>

# %% [markdown]
# <h3>3.1.1. Reading Gene and Variation Data</h3>

# %%
data = pd.read_csv('training_variants')
print('Number of data points : ', data.shape[0])
print('Number of features : ', data.shape[1])
print('Features : ', data.columns.values)
data.head()
# Out:
# Number of data points :  3321
# Number of features :  4
# Features :  ['ID' 'Gene' 'Variation' 'Class']
#    ID    Gene             Variation  Class
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4

# %% [markdown]
# <p>
#     training_variants is a comma separated file containing the description of the genetic mutations used for training. <br>
#     Fields are
#     <ul>
#         <li><b>ID : </b>the id of the row used to link the mutation to the clinical evidence</li>
#         <li><b>Gene : </b>the gene where this genetic mutation is located </li>
#         <li><b>Variation : </b>the aminoacid change for this mutations </li>
#         <li><b>Class :</b> 1-9 the class this genetic mutation has been classified on</li>
#     </ul>

# %% [markdown]
# <h3>3.1.2. Reading Text Data</h3>

# %%
# note the seprator in this file
data_text =pd.read_csv("training_text",sep="\|\|",engine="python",names=["ID","TEXT"],skiprows=1)
print('Number of data points : ', data_text.shape[0])
print('Number of features : ', data_text.shape[1])
print('Features : ', data_text.columns.values)
data_text.head()
# Out:
# Number of data points :  3321
# Number of features :  2
# Features :  ['ID' 'TEXT']
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...
# 2   2   Abstract Background  Non-small cell lung canc...
# 3   3  Recent evidence has demonstrated that acquired...
# 4   4  Oncogenic mutations in the monomeric Casitas B...

# %% [markdown]
# <h3>3.1.3. Preprocessing of text</h3>

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/bharath/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# loading stop words from nltk library
stop_words = set(stopwords.words('english'))


def nlp_preprocessing(total_text, index, column):
    if type(total_text) is not int:
        string = ""
        # replace every special char with space
        total_text = re.sub('[^a-zA-Z0-9\n]', ' ', total_text)
        # replace multiple spaces with single space
        total_text = re.sub('\s+',' ', total_text)
        # converting all the chars into lower-case.
        total_text = total_text.lower()
        
        for word in total_text.split():
        # if the word is a not a stop word then retain that word from the data
            if not word in stop_words:
                string += word + " "
        
        data_text[column][index] = string

# %%
data_text.head(2)
# Out:
#    ID                                               TEXT
# 0   0  Cyclin-dependent kinases (CDKs) regulate a var...
# 1   1   Abstract Background  Non-small cell lung canc...

# %%
#text processing stage.
start_time = time.perf_counter()
for index, row in data_text.iterrows():
    if type(row['TEXT']) is str:
        nlp_preprocessing(row['TEXT'], index, 'TEXT')
    else:
        print("there is no text description for id:",index)
print('Time took for preprocessing the text :',time.perf_counter() - start_time, "seconds")
# Out:
# there is no text description for id: 1109
# there is no text description for id: 1277
# there is no text description for id: 1407
# there is no text description for id: 1639
# there is no text description for id: 2755
# Time took for preprocessing the text : 28.815513579999788 seconds

# %%
#merging both gene_variations and text data based on ID
result = pd.merge(data, data_text,on='ID', how='left')
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT
# 0  cyclin dependent kinases cdks regulate variety...
# 1  abstract background non small cell lung cancer...
# 2  abstract background non small cell lung cancer...
# 3  recent evidence demonstrated acquired uniparen...
# 4  oncogenic mutations monomeric casitas b lineag...

# %%
result[result.isnull().any(axis=1)]
# Out:
#         ID    Gene             Variation  Class TEXT
# 1109  1109   FANCA                S1088F      1  NaN
# 1277  1277  ARID5B  Truncating Mutations      1  NaN
# 1407  1407   FGFR3                 K508M      6  NaN
# 1639  1639    FLT1         Amplification      6  NaN
# 2755  2755    BRAF                 G596C      7  NaN

# %%
result.loc[result['TEXT'].isnull(),'TEXT'] = result['Gene'] +' '+result['Variation']

# %%
result[result['ID']==1109]
# Out:
#         ID   Gene Variation  Class          TEXT
# 1109  1109  FANCA    S1088F      1  FANCA S1088F

# %%
result['freq_gene'] = result.groupby('Gene')['Gene'].transform('count') 
result['freq_var'] = result.groupby('Variation')['Variation'].transform('count')
result['text_len'] = result['TEXT'].str.len()

# %%
result.head()
# Out:
#    ID    Gene             Variation  Class  \
# 0   0  FAM58A  Truncating Mutations      1
# 1   1     CBL                 W802*      2
# 2   2     CBL                 Q249E      2
# 3   3     CBL                 N454D      3
# 4   4     CBL                 L399V      4
#
#                                                 TEXT  freq_gene  freq_var  \
# 0  cyclin dependent kinases cdks regulate variety...          1        93
# 1  abstract background non small cell lung cancer...         25         1
# 2  abstract background non small cell lung cancer...         25         1
# 3  recent evidence demonstrated acquired uniparen...         25         1
# 4  oncogenic mutations monomeric casitas b lineag...         25         1
#
#    text_len
# 0     30836
# 1     27844
# 2     27844
# 3     28093
# 4     31649

# %% [markdown]
# <h3>3.1.4. Test, Train and Cross Validation Split</h3>

# %% [markdown]
# <h4>3.1.4.1. Splitting data into train, test and cross validation (64:20:16)</h4>

# %%
y_true = result['Class'].values
result.Gene      = result.Gene.str.replace('\s+', '_')
result.Variation = result.Variation.str.replace('\s+', '_')

# split the data into test and train by maintaining same distribution of output varaible 'y_true' [stratify=y_true]
X_train, test_df, y_train, y_test = train_test_split(result, y_true, stratify=y_true, test_size=0.2)
# split the train data into train and cross validation by maintaining same distribution of output varaible 'y_train' [stratify=y_train]
train_df, cv_df, y_train, y_cv = train_test_split(X_train, y_train, stratify=y_train, test_size=0.2)

# %%
print("After vectorizations")
print(train_df.shape, y_train.shape)
print(cv_df.shape, y_cv.shape)
print(test_df.shape, y_test.shape)
print("="*100)
# Out:
# After vectorizations
# (2124, 8) (2124,)
# (532, 8) (532,)
# (665, 8) (665,)
# ====================================================================================================

# %% [markdown]
# <p> We split the data into train, test and cross validation data sets, preserving the ratio of class distribution in the original data set  </p>

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

normalizer.fit(X_train['freq_gene'].values.reshape(-1,1))

train_gene_freq = normalizer.transform(train_df['freq_gene'].values.reshape(-1,1))
cv_gene_freq = normalizer.transform(cv_df['freq_gene'].values.reshape(-1,1))
test_gene_freq = normalizer.transform(test_df['freq_gene'].values.reshape(-1,1))

print("After vectorizations")
print(train_gene_freq.shape, y_train.shape)
print(cv_gene_freq.shape, y_cv.shape)
print(test_gene_freq.shape, y_test.shape)
print("="*100)
# Out:
# After vectorizations
# (2124, 1) (2124,)
# (532, 1) (532,)
# (665, 1) (665,)
# ====================================================================================================

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

normalizer.fit(X_train['freq_var'].values.reshape(-1,1))

train_var_freq = normalizer.transform(train_df['freq_var'].values.reshape(-1,1))
cv_var_freq = normalizer.transform(cv_df['freq_var'].values.reshape(-1,1))
test_var_freq = normalizer.transform(test_df['freq_var'].values.reshape(-1,1))

print("After vectorizations")
print(train_var_freq.shape, y_train.shape)
print(cv_var_freq.shape, y_cv.shape)
print(test_var_freq.shape, y_test.shape)
print("="*100)
# Out:
# After vectorizations
# (2124, 1) (2124,)
# (532, 1) (532,)
# (665, 1) (665,)
# ====================================================================================================

# %%
from sklearn.preprocessing import Normalizer
normalizer = Normalizer()

normalizer.fit(X_train['text_len'].values.reshape(-1,1))

train_text_len = normalizer.transform(train_df['text_len'].values.reshape(-1,1))
cv_text_len = normalizer.transform(cv_df['text_len'].values.reshape(-1,1))
test_text_len = normalizer.transform(test_df['text_len'].values.reshape(-1,1))

print("After vectorizations")
print(train_text_len.shape, y_train.shape)
print(cv_text_len.shape, y_cv.shape)
print(test_text_len.shape, y_test.shape)
print("="*100)
# Out:
# After vectorizations
# (2124, 1) (2124,)
# (532, 1) (532,)
# (665, 1) (665,)
# ====================================================================================================

# %%
print('Number of data points in train data:', train_df.shape[0])
print('Number of data points in test data:', test_df.shape[0])
print('Number of data points in cross validation data:', cv_df.shape[0])
# Out:
# Number of data points in train data: 2124
# Number of data points in test data: 665
# Number of data points in cross validation data: 532

# %% [markdown]
# <h4>3.1.4.2. Distribution of y_i's in Train, Test and Cross Validation datasets</h4>

# %%
# it returns a dict, keys as class labels and values as the number of data points in that class
train_class_distribution = train_df['Class'].value_counts().sort_index()
test_class_distribution = test_df['Class'].value_counts().sort_index()
cv_class_distribution = cv_df['Class'].value_counts().sort_index()

#my_colors = 'rgbkymc'
my_colors = ['r', 'g', 'b', 'k', 'y', 'm', 'c']
train_class_distribution.plot(kind='bar',color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in train data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',train_class_distribution.values[i], '(', np.round((train_class_distribution.values[i]/train_df.shape[0]*100), 3), '%)')

    
print('-'*80)
#my_colors = 'rgbkymc'
test_class_distribution.plot(kind='bar',color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in test data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-test_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',test_class_distribution.values[i], '(', np.round((test_class_distribution.values[i]/test_df.shape[0]*100), 3), '%)')

print('-'*80)
#my_colors = 'rgbkymc'
cv_class_distribution.plot(kind='bar',color=my_colors)
plt.xlabel('Class')
plt.ylabel('Data points per Class')
plt.title('Distribution of yi in cross validation data')
plt.grid()
plt.show()

# ref: argsort https://docs.scipy.org/doc/numpy/reference/generated/numpy.argsort.html
# -(train_class_distribution.values): the minus sign will give us in decreasing order
sorted_yi = np.argsort(-train_class_distribution.values)
for i in sorted_yi:
    print('Number of data points in class', i+1, ':',cv_class_distribution.values[i], '(', np.round((cv_class_distribution.values[i]/cv_df.shape[0]*100), 3), '%)')
# Out:
# Number of data points in class 7 : 609 ( 28.672 %)
# Number of data points in class 4 : 439 ( 20.669 %)
# Number of data points in class 1 : 363 ( 17.09 %)
# Number of data points in class 2 : 289 ( 13.606 %)
# Number of data points in class 6 : 176 ( 8.286 %)
# Number of data points in class 5 : 155 ( 7.298 %)
# Number of data points in class 3 : 57 ( 2.684 %)
# Number of data points in class 9 : 24 ( 1.13 %)
# Number of data points in class 8 : 12 ( 0.565 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 191 ( 28.722 %)
# Number of data points in class 4 : 137 ( 20.602 %)
# Number of data points in class 1 : 114 ( 17.143 %)
# Number of data points in class 2 : 91 ( 13.684 %)
# Number of data points in class 6 : 55 ( 8.271 %)
# Number of data points in class 5 : 48 ( 7.218 %)
# Number of data points in class 3 : 18 ( 2.707 %)
# Number of data points in class 9 : 7 ( 1.053 %)
# Number of data points in class 8 : 4 ( 0.602 %)
# --------------------------------------------------------------------------------
# Number of data points in class 7 : 153 ( 28.759 %)
# Number of data points in class 4 : 110 ( 20.677 %)
# Number of data points in class 1 : 91 ( 17.105 %)
# Number of data points in class 2 : 72 ( 13.534 %)
# Number of data points in class 6 : 44 ( 8.271 %)
# Number of data points in class 5 : 39 ( 7.331 %)
# Number of data points in class 3 : 14 ( 2.632 %)
# Number of data points in class 9 : 6 ( 1.128 %)
# Number of data points in class 8 : 3 ( 0.564 %)

# %% [markdown]
# <h2>3.2 Prediction using a 'Random' Model</h2>

# %% [markdown]
# <p style="font-size:16px"> In a 'Random' Model, we generate the NINE class probabilites randomly such that they sum to 1. </p>

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    
    labels = [1,2,3,4,5,6,7,8,9]
    # representing A in heatmap format
    print("-"*20, "Confusion matrix", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(C, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

    print("-"*20, "Precision matrix (Columm Sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(B, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()
    
    # representing B in heatmap format
    print("-"*20, "Recall matrix (Row sum=1)", "-"*20)
    plt.figure(figsize=(20,7))
    sns.heatmap(A, annot=True, cmap="YlGnBu", fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
test_data_len = test_df.shape[0]
cv_data_len = cv_df.shape[0]

# we create a output array that has exactly same size as the CV data
cv_predicted_y = np.zeros((cv_data_len,9))
for i in range(cv_data_len):
    rand_probs = np.random.rand(1,9)
    cv_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Cross Validation Data using Random Model",log_loss(y_cv,cv_predicted_y, eps=1e-15))


# Test-Set error.
#we create a output array that has exactly same as the test data
test_predicted_y = np.zeros((test_data_len,9))
for i in range(test_data_len):
    rand_probs = np.random.rand(1,9)
    test_predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test,test_predicted_y, eps=1e-15))

predicted_y =np.argmax(test_predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y+1)
# Out:
# Log loss on Cross Validation Data using Random Model 2.5057782413413254
# Log loss on Test Data using Random Model 2.436297908332307
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h2>3.3 Univariate Analysis</h2>

# %%
# code for response coding with Laplace smoothing.
# alpha : used for laplace smoothing
# feature: ['gene', 'variation']
# df: ['train_df', 'test_df', 'cv_df']
# algorithm
# ----------
# Consider all unique values and the number of occurances of given feature in train data dataframe
# build a vector (1*9) , the first element = (number of times it occured in class1 + 10*alpha / number of time it occurred in total data+90*alpha)
# gv_dict is like a look up table, for every gene it store a (1*9) representation of it
# for a value of feature in df:
# if it is in train data:
# we add the vector that was stored in 'gv_dict' look up table to 'gv_fea'
# if it is not there is train:
# we add [1/9, 1/9, 1/9, 1/9,1/9, 1/9, 1/9, 1/9, 1/9] to 'gv_fea'
# return 'gv_fea'
# ----------------------
from sklearn.feature_extraction.text import TfidfVectorizer
# get_gv_fea_dict: Get Gene varaition Feature Dict
def get_gv_fea_dict(alpha, feature, df):
    # value_count: it contains a dict like
    # print(train_df['Gene'].value_counts())
    # output:
    #        {BRCA1      174
    #         TP53       106
    #         EGFR        86
    #         BRCA2       75
    #         PTEN        69
    #         KIT         61
    #         BRAF        60
    #         ERBB2       47
    #         PDGFRA      46
    #         ...}
    # print(train_df['Variation'].value_counts())
    # output:
    # {
    # Truncating_Mutations                     63
    # Deletion                                 43
    # Amplification                            43
    # Fusions                                  22
    # Overexpression                            3
    # E17K                                      3
    # Q61L                                      3
    # S222D                                     2
    # P130S                                     2
    # ...
    # }
    value_count = train_df[feature].value_counts()
    
    # gv_dict : Gene Variation Dict, which contains the probability array for each gene/variation
    gv_dict = dict()
    
    # denominator will contain the number of time that particular feature occured in whole data
    for i, denominator in value_count.items():
        # vec will contain (p(yi==1/Gi) probability of gene/variation belongs to perticular class
        # vec is 9 diamensional vector
        vec = []
        for k in range(1,10):
            # print(train_df.loc[(train_df['Class']==1) & (train_df['Gene']=='BRCA1')])
            #         ID   Gene             Variation  Class  
            # 2470  2470  BRCA1                S1715C      1   
            # 2486  2486  BRCA1                S1841R      1   
            # 2614  2614  BRCA1                   M1R      1   
            # 2432  2432  BRCA1                L1657P      1   
            # 2567  2567  BRCA1                T1685A      1   
            # 2583  2583  BRCA1                E1660G      1   
            # 2634  2634  BRCA1                W1718L      1   
            # cls_cnt.shape[0] will return the number of rows

            cls_cnt = train_df.loc[(train_df['Class']==k) & (train_df[feature]==i)]
            
            # cls_cnt.shape[0](numerator) will contain the number of time that particular feature occured in whole data
            vec.append((cls_cnt.shape[0] + alpha*10)/ (denominator + 90*alpha))

        # we are adding the gene/variation to the dict as key and vec as value
        gv_dict[i]=vec
    return gv_dict

# Get Gene variation feature
def get_gv_feature(alpha, feature, df):
    # print(gv_dict)
    #     {'BRCA1': [0.20075757575757575, 0.03787878787878788, 0.068181818181818177, 0.13636363636363635, 0.25, 0.19318181818181818, 0.03787878787878788, 0.03787878787878788, 0.03787878787878788], 
    #      'TP53': [0.32142857142857145, 0.061224489795918366, 0.061224489795918366, 0.27040816326530615, 0.061224489795918366, 0.066326530612244902, 0.051020408163265307, 0.051020408163265307, 0.056122448979591837], 
    #      'EGFR': [0.056818181818181816, 0.21590909090909091, 0.0625, 0.068181818181818177, 0.068181818181818177, 0.0625, 0.34659090909090912, 0.0625, 0.056818181818181816], 
    #      'BRCA2': [0.13333333333333333, 0.060606060606060608, 0.060606060606060608, 0.078787878787878782, 0.1393939393939394, 0.34545454545454546, 0.060606060606060608, 0.060606060606060608, 0.060606060606060608], 
    #      'PTEN': [0.069182389937106917, 0.062893081761006289, 0.069182389937106917, 0.46540880503144655, 0.075471698113207544, 0.062893081761006289, 0.069182389937106917, 0.062893081761006289, 0.062893081761006289], 
    #      'KIT': [0.066225165562913912, 0.25165562913907286, 0.072847682119205295, 0.072847682119205295, 0.066225165562913912, 0.066225165562913912, 0.27152317880794702, 0.066225165562913912, 0.066225165562913912], 
    #      'BRAF': [0.066666666666666666, 0.17999999999999999, 0.073333333333333334, 0.073333333333333334, 0.093333333333333338, 0.080000000000000002, 0.29999999999999999, 0.066666666666666666, 0.066666666666666666],
    #      ...
    #     }
    gv_dict = get_gv_fea_dict(alpha, feature, df)
    # value_count is similar in get_gv_fea_dict
    value_count = train_df[feature].value_counts()
    
    # gv_fea: Gene_variation feature, it will contain the feature for each feature value in the data
    gv_fea = []
    # for every feature values in the given data frame we will check if it is there in the train data then we will add the feature to gv_fea
    # if not we will add [1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9] to gv_fea
    for index, row in df.iterrows():
        if row[feature] in dict(value_count).keys():
            gv_fea.append(gv_dict[row[feature]])
        else:
            gv_fea.append([1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9,1/9])
#             gv_fea.append([-1,-1,-1,-1,-1,-1,-1,-1,-1])
    return gv_fea

# %% [markdown]
# when we caculate the probability of a feature belongs to any particular class, we apply laplace smoothing
# <li>(numerator + 10\*alpha) / (denominator + 90\*alpha) </li>

# %% [markdown]
# <h3>3.2.1 Univariate Analysis on Gene Feature</h3>

# %%
unique_genes = train_df['Gene'].value_counts()
print('Number of Unique Genes :', unique_genes.shape[0])
# the top 10 genes that occured most
print(unique_genes.head(10))
# Out:
# Number of Unique Genes : 232
# BRCA1     167
# TP53      113
# EGFR       89
# PTEN       79
# BRCA2      78
# KIT        63
# BRAF       55
# ERBB2      47
# PIK3CA     40
# ALK        38
# Name: Gene, dtype: int64

# %%
print("Ans: There are", unique_genes.shape[0] ,"different categories of genes in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 232 different categories of genes in the train data, and they are distibuted as follows

# %%
s = sum(unique_genes.values);
h = unique_genes.values/s;
plt.plot(h, label="Histrogram of Genes")
plt.xlabel('Index of a Gene')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
plt.plot(c,label='Cumulative distribution of Genes')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# </b>there are two ways we can featurize this variable
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will choose the appropriate featurization based on the ML model we use.  For this problem of multi-class classification with categorical features, one-hot encoding is better for Logistic regression while response coding is better for Random Forests. </p>

# %%
#response-coding of the Gene feature
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", train_df))
# test gene feature
test_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", test_df))
# cross validation gene feature
cv_gene_feature_responseCoding = np.array(get_gv_feature(alpha, "Gene", cv_df))

# %%
print("train_gene_featutrain_gene_feature_responseCoding.shapere_responseCoding is converted feature using respone coding method. The shape of gene feature:", train_gene_feature_responseCoding.shape)
# Out:
# train_gene_featutrain_gene_feature_responseCoding.shapere_responseCoding is converted feature using respone coding method. The shape of gene feature: (2124, 9)

# %%
# one-hot encoding of Gene feature.
gene_vectorizer = CountVectorizer(min_df=10,ngram_range=(1,2), max_features=1000)
train_gene_feature_onehotCoding = gene_vectorizer.fit_transform(train_df['Gene'])
test_gene_feature_onehotCoding = gene_vectorizer.transform(test_df['Gene'])
cv_gene_feature_onehotCoding = gene_vectorizer.transform(cv_df['Gene'])

# %%
train_df['Gene'].head()
# Out:
# 1237     PIM1
# 2526    BRCA1
# 1804     ARAF
# 2206     PTEN
# 2598    BRCA1
# Name: Gene, dtype: object

# %%
gene_vectorizer.get_feature_names()
# Out:
# ['abl1',
#  'akt1',
#  'alk',
#  'ar',
#  'braf',
#  'brca1',
#  'brca2',
#  'cbl',
#  'cdkn2a',
#  'ctnnb1',
#  'egfr',
#  'erbb2',
#  'erbb4',
#  'esr1',
#  'fbxw7',
#  'fgfr1',
#  'fgfr2',
#  'fgfr3',
#  'flt3',
#  'hras',
#  'jak1',
#  'jak2',
#  'kit',
#  'kras',
#  'map2k1',
#  'map2k2',
#  'met',
#  'mlh1',
#  'msh2',
#  'msh6',
#  'mtor',
#  'nfe2l2',
#  'notch1',
#  'ntrk1',
#  'pdgfra',
#  'pdgfrb',
#  'pik3ca',
#  'pik3r1',
#  'pms2',
#  'ppp2r1a',
#  'pten',
#  'ptpn11',
#  'ptprt',
#  'ret',
#  'ros1',
#  'runx1',
#  'sf3b1',
#  'smad2',
#  'smad3',
#  'smad4',
#  'smo',
#  'spop',
#  'tet2',
#  'tp53',
#  'tsc1',
#  'tsc2',
#  'vhl']

# %%
print("train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature:", train_gene_feature_onehotCoding.shape)
# Out:
# train_gene_feature_onehotCoding is converted feature using one-hot encoding method. The shape of gene feature: (2124, 57)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q4.</b> How good is this gene feature  in predicting y_i?</p>

# %% [markdown]
# There are many ways to estimate how good a feature is, in predicting y_i. One of the good methods is to build a proper ML model using just this feature. In this case, we will build a logistic regression model using only Gene feature (one hot encoded) to predict y_i.

# %%
alpha = [10 ** x for x in range(-5, 1)] # hyperparam for SGD classifier.

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_gene_feature_onehotCoding, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_gene_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_gene_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_gene_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_gene_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.2705845878355786
# For values of alpha =  0.0001 The log loss is: 1.2572403259497231
# For values of alpha =  0.001 The log loss is: 1.276528506281574
# For values of alpha =  0.01 The log loss is: 1.3423808509341755
# For values of alpha =  0.1 The log loss is: 1.444363039218245
# For values of alpha =  1 The log loss is: 1.484945684192004
# For values of best alpha =  0.0001 The train log loss is: 1.2249233292456043
# For values of best alpha =  0.0001 The cross validation log loss is: 1.2572403259497231
# For values of best alpha =  0.0001 The test log loss is: 1.3020660372012962

# %% [markdown]
# <p style="font-size:18px;"> <b>Q5.</b> Is the Gene feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it is. Otherwise, the CV and Test errors would be significantly more than train error. </p>

# %%
print("Q6. How many data points in Test and CV datasets are covered by the ", unique_genes.shape[0], " genes in train dataset?")

test_coverage=test_df[test_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]
cv_coverage=cv_df[cv_df['Gene'].isin(list(set(train_df['Gene'])))].shape[0]

print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q6. How many data points in Test and CV datasets are covered by the  232  genes in train dataset?
# Ans
# 1. In test data 644 out of 665 : 96.84210526315789
# 2. In cross validation data 515 out of  532 : 96.80451127819549

# %% [markdown]
# <h3>3.2.2 Univariate Analysis on Variation Feature</h3>

# %% [markdown]
# <p style="font-size:18px;"> <b>Q7.</b> Variation, What type of feature is it ?</p>
# <p style="font-size:16px;"><b>Ans.</b> Variation is a categorical variable </p>
# <p style="font-size:18px;"> <b>Q8.</b> How many categories are there?</p>

# %%
unique_variations = train_df['Variation'].value_counts()
print('Number of Unique Variations :', unique_variations.shape[0])
# the top 10 variations that occured most
print(unique_variations.head(10))
# Out:
# Number of Unique Variations : 1925
# Truncating_Mutations    66
# Deletion                47
# Amplification           46
# Fusions                 17
# G12V                     4
# Q61R                     3
# E17K                     3
# T58I                     3
# A146T                    2
# I31M                     2
# Name: Variation, dtype: int64

# %%
print("Ans: There are", unique_variations.shape[0] ,"different categories of variations in the train data, and they are distibuted as follows",)
# Out:
# Ans: There are 1925 different categories of variations in the train data, and they are distibuted as follows

# %%
s = sum(unique_variations.values);
h = unique_variations.values/s;
plt.plot(h, label="Histrogram of Variations")
plt.xlabel('Index of a Variation')
plt.ylabel('Number of Occurances')
plt.legend()
plt.grid()
plt.show()

# %%
c = np.cumsum(h)
print(c)
plt.plot(c,label='Cumulative distribution of Variations')
plt.grid()
plt.legend()
plt.show()
# Out:
# [0.03107345 0.05320151 0.07485876 ... 0.99905838 0.99952919 1.        ]

# %% [markdown]
# <p style="font-size:18px;"> <b>Q9.</b> How to featurize this Variation feature ?</p>
#
# <p style="font-size:16px;"><b>Ans.</b>There are two ways we can featurize this variable
# check out this video: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/handling-categorical-and-numerical-features/
# <ol><li>One hot Encoding</li><li>Response coding</li></ol></p>
# <p> We will be using both these methods to featurize the Variation Feature </p>

# %%
# alpha is used for laplace smoothing
alpha = 1
# train gene feature
train_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", train_df))
# test gene feature
test_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", test_df))
# cross validation gene feature
cv_variation_feature_responseCoding = np.array(get_gv_feature(alpha, "Variation", cv_df))

# %%
print("train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature:", train_variation_feature_responseCoding.shape)
# Out:
# train_variation_feature_responseCoding is a converted feature using the response coding method. The shape of Variation feature: (2124, 9)

# %%
# one-hot encoding of variation feature.
variation_vectorizer = CountVectorizer(min_df=10,ngram_range=(1,2), max_features=1000)
train_variation_feature_onehotCoding = variation_vectorizer.fit_transform(train_df['Variation'])
test_variation_feature_onehotCoding = variation_vectorizer.transform(test_df['Variation'])
cv_variation_feature_onehotCoding = variation_vectorizer.transform(cv_df['Variation'])

# %%
print("train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature:", train_variation_feature_onehotCoding.shape)
# Out:
# train_variation_feature_onehotEncoded is converted feature using the onne-hot encoding method. The shape of Variation feature: (2124, 5)

# %% [markdown]
# <p style="font-size:18px;"> <b>Q10.</b> How good is this Variation feature  in predicting y_i?</p>

# %% [markdown]
# Let's build a model just like the earlier!

# %%
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_variation_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_variation_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
    
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_variation_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_variation_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_variation_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.7352762224210903
# For values of alpha =  0.0001 The log loss is: 1.7303546784647863
# For values of alpha =  0.001 The log loss is: 1.7341711432565738
# For values of alpha =  0.01 The log loss is: 1.738001157411793
# For values of alpha =  0.1 The log loss is: 1.7452544228351912
# For values of alpha =  1 The log loss is: 1.7484255800817636
# For values of best alpha =  0.0001 The train log loss is: 1.7195172959324758
# For values of best alpha =  0.0001 The cross validation log loss is: 1.7303546784647863
# For values of best alpha =  0.0001 The test log loss is: 1.733563784999526

# %% [markdown]
# <p style="font-size:18px;"> <b>Q11.</b> Is the Variation feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Not sure! But lets be very sure using the below analysis. </p>

# %%
print("Q12. How many data points are covered by total ", unique_variations.shape[0], " genes in test and cross validation data sets?")
test_coverage=test_df[test_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
cv_coverage=cv_df[cv_df['Variation'].isin(list(set(train_df['Variation'])))].shape[0]
print('Ans\n1. In test data',test_coverage, 'out of',test_df.shape[0], ":",(test_coverage/test_df.shape[0])*100)
print('2. In cross validation data',cv_coverage, 'out of ',cv_df.shape[0],":" ,(cv_coverage/cv_df.shape[0])*100)
# Out:
# Q12. How many data points are covered by total  1925  genes in test and cross validation data sets?
# Ans
# 1. In test data 64 out of 665 : 9.624060150375941
# 2. In cross validation data 51 out of  532 : 9.586466165413533

# %% [markdown]
# <h3>3.2.3 Univariate Analysis on Text Feature</h3>

# %% [markdown]
# 1. How many unique words are present in train data?
# 2. How are word frequencies distributed?
# 3. How to featurize text field?
# 4. Is the text feature useful in predicitng y_i?
# 5. Is the text feature stable across train, test and CV datasets?

# %%
# cls_text is a data frame
# for every row in data fram consider the 'TEXT'
# split the words by space
# make a dict with those words
# increment its count whenever we see that word

def extract_dictionary_paddle(cls_text):
    dictionary = defaultdict(int)
    for index, row in cls_text.iterrows():
        for word in row['TEXT'].split():
            dictionary[word] +=1
    return dictionary

# %%
import math
#https://stackoverflow.com/a/1602964
def get_text_responsecoding(df):
    text_feature_responseCoding = np.zeros((df.shape[0],9))
    for i in range(0,9):
        row_index = 0
        for index, row in df.iterrows():
            sum_prob = 0
            for word in row['TEXT'].split():
                sum_prob += math.log(((dict_list[i].get(word,0)+10 )/(total_dict.get(word,0)+90)))
            text_feature_responseCoding[row_index][i] = math.exp(sum_prob/len(row['TEXT'].split()))
            row_index += 1
    return text_feature_responseCoding

# %%
# building a CountVectorizer with all the words that occured minimum 3 times in train data
text_vectorizer = CountVectorizer(min_df=3,ngram_range=(1,2), max_features=1000)
train_text_feature_onehotCoding = text_vectorizer.fit_transform(train_df['TEXT'])
# getting all the feature names (words)
train_text_features= text_vectorizer.get_feature_names()

# train_text_feature_onehotCoding.sum(axis=0).A1 will sum every row and returns (1*number of features) vector
train_text_fea_counts = train_text_feature_onehotCoding.sum(axis=0).A1

# zip(list(text_features),text_fea_counts) will zip a word with its number of times it occured
text_fea_dict = dict(zip(list(train_text_features),train_text_fea_counts))


print("Total number of unique words in train data :", len(train_text_features))
# Out:
# Total number of unique words in train data : 1000

# %%
dict_list = []
# dict_list =[] contains 9 dictoinaries each corresponds to a class
for i in range(1,10):
    cls_text = train_df[train_df['Class']==i]
    # build a word dict based on the words in that class
    dict_list.append(extract_dictionary_paddle(cls_text))
    # append it to dict_list

# dict_list[i] is build on i'th  class text data
# total_dict is buid on whole training text data
total_dict = extract_dictionary_paddle(train_df)


confuse_array = []
for i in train_text_features:
    ratios = []
    max_val = -1
    for j in range(0,9):
        ratios.append((dict_list[j][i]+10 )/(total_dict[i]+90))
    confuse_array.append(ratios)
confuse_array = np.array(confuse_array)

# %%
#response coding of text features
train_text_feature_responseCoding  = get_text_responsecoding(train_df)
test_text_feature_responseCoding  = get_text_responsecoding(test_df)
cv_text_feature_responseCoding  = get_text_responsecoding(cv_df)

# %%
# https://stackoverflow.com/a/16202486
# we convert each row values such that they sum to 1  
train_text_feature_responseCoding = (train_text_feature_responseCoding.T/train_text_feature_responseCoding.sum(axis=1)).T
test_text_feature_responseCoding = (test_text_feature_responseCoding.T/test_text_feature_responseCoding.sum(axis=1)).T
cv_text_feature_responseCoding = (cv_text_feature_responseCoding.T/cv_text_feature_responseCoding.sum(axis=1)).T

# %%
# don't forget to normalize every feature
train_text_feature_onehotCoding = normalize(train_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
test_text_feature_onehotCoding = text_vectorizer.transform(test_df['TEXT'])
# don't forget to normalize every feature
test_text_feature_onehotCoding = normalize(test_text_feature_onehotCoding, axis=0)

# we use the same vectorizer that was trained on train data
cv_text_feature_onehotCoding = text_vectorizer.transform(cv_df['TEXT'])
# don't forget to normalize every feature
cv_text_feature_onehotCoding = normalize(cv_text_feature_onehotCoding, axis=0)

# %%
#https://stackoverflow.com/a/2258273/4084039
sorted_text_fea_dict = dict(sorted(text_fea_dict.items(), key=lambda x: x[1] , reverse=True))
sorted_text_occur = np.array(list(sorted_text_fea_dict.values()))

# %%
# Number of words for a given frequency.
print(Counter(sorted_text_occur))
# Out:
# Counter({3040: 4, 4409: 3, 3042: 3, 2824: 3, 9814: 2, 8256: 2, 6353: 2, 6262: 2, 5905: 2, 5357: 2, 5243: 2, 5205: 2, 4886: 2, 4806: 2, 4429: 2, 4426: 2, 4230: 2, 4208: 2, 4026: 2, 4018: 2, 3993: 2, 3983: 2, 3903: 2, 3852: 2, 3820: 2, 3803: 2, 3754: 2, 3717: 2, 3706: 2, 3705: 2, 3668: 2, 3607: 2, 3593: 2, 3580: 2, 3535: 2, 3506: 2, 3451: 2, 3406: 2, 3381: 2, 3334: 2, 3313: 2, 3237: 2, 3226: 2, 3225: 2, 3211: 2, 3179: 2, 3171: 2, 3103: 2, 3093: 2, 2996: 2, 2984: 2, 2962: 2, 2960: 2, 2936: 2, 2926: 2, 2916: 2, 2901: 2, 2882: 2, 2842: 2, 151520: 1, 119284: 1, 82320: 1, 67294: 1, 67063: 1, 64384: 1, 63678: 1, 63578: 1, 63008: 1, 62948: 1, 54709: 1, 53996: 1, 49599: 1, 48450: 1, 47055: 1, 46515: 1, 45396: 1, 42532: 1, 42353: 1, 42002: 1, 41300: 1, 41130: 1, 40934: 1, 40344: 1, 39048: 1, 38660: 1, 37561: 1, 37499: 1, 36614: 1, 36562: 1, 36223: 1, 34701: 1, 34404: 1, 33860: 1, 33354: 1, 32934: 1, 31962: 1, 31513: 1, 29757: 1, 28469: 1, 28243: 1, 27510: 1, 26118: 1, 25984: 1, 25453: 1, 25360: 1, 24933: 1, 24800: 1, 24677: 1, 24292: 1, 24094: 1, 23751: 1, 23704: 1, 23528: 1, 23311: 1, 22580: 1, 22123: 1, 21973: 1, 21871: 1, 21791: 1, 21423: 1, 21187: 1, 20725: 1, 20158: 1, 20065: 1, 20039: 1, 19967: 1, 19753: 1, 19469: 1, 19374: 1, 19326: 1, 19241: 1, 19183: 1, 18832: 1, 18789: 1, 18781: 1, 18739: 1, 18689: 1, 18326: 1, 18156: 1, 18044: 1, 17975: 1, 17949: 1, 17842: 1, 17837: 1, 17772: 1, 17539: 1, 17458: 1, 17393: 1, 17336: 1, 17280: 1, 17125: 1, 17122: 1, 17092: 1, 16942: 1, 16843: 1, 16731: 1, 16656: 1, 16490: 1, 16411: 1, 16108: 1, 16084: 1, 15848: 1, 15681: 1, 15596: 1, 15545: 1, 15493: 1, 15450: 1, 15447: 1, 15219: 1, 15182: 1, 15168: 1, 15063: 1, 15011: 1, 14832: 1, 14802: 1, 14759: 1, 14736: 1, 14710: 1, 14660: 1, 14443: 1, 14325: 1, 14300: 1, 14261: 1, 14224: 1, 14203: 1, 14116: 1, 13933: 1, 13697: 1, 13630: 1, 13551: 1, 13530: 1, 13278: 1, 13248: 1, 13225: 1, 13050: 1, 12929: 1, 12925: 1, 12903: 1, 12823: 1, 12713: 1, 12707: 1, 12692: 1, 12668: 1, 12660: 1, 12655: 1, 12653: 1, 12646: 1, 12535: 1, 12531: 1, 12506: 1, 12493: 1, 12466: 1, 12442: 1, 12402: 1, 12263: 1, 12244: 1, 12230: 1, 12200: 1, 12199: 1, 12191: 1, 12168: 1, 12156: 1, 12142: 1, 12129: 1, 11966: 1, 11922: 1, 11916: 1, 11865: 1, 11829: 1, 11808: 1, 11729: 1, 11689: 1, 11663: 1, 11642: 1, 11615: 1, 11594: 1, 11587: 1, 11559: 1, 11483: 1, 11358: 1, 11341: 1, 11312: 1, 11246: 1, 11158: 1, 11125: 1, 10989: 1, 10896: 1, 10890: 1, 10613: 1, 10599: 1, 10598: 1, 10593: 1, 10543: 1, 10424: 1, 10403: 1, 10306: 1, 10305: 1, 10278: 1, 10205: 1, 10200: 1, 10187: 1, 10135: 1, 10133: 1, 10100: 1, 10084: 1, 10081: 1, 10040: 1, 9986: 1, 9966: 1, 9896: 1, 9875: 1, 9836: 1, 9711: 1, 9710: 1, 9650: 1, 9636: 1, 9605: 1, 9586: 1, 9584: 1, 9450: 1, 9438: 1, 9403: 1, 9375: 1, 9374: 1, 9333: 1, 9296: 1, 9245: 1, 9221: 1, 9187: 1, 9166: 1, 9157: 1, 9140: 1, 9118: 1, 9096: 1, 9074: 1, 9071: 1, 9057: 1, 9055: 1, 9051: 1, 9034: 1, 9033: 1, 8997: 1, 8985: 1, 8975: 1, 8875: 1, 8792: 1, 8715: 1, 8680: 1, 8670: 1, 8669: 1, 8658: 1, 8572: 1, 8560: 1, 8482: 1, 8450: 1, 8432: 1, 8361: 1, 8350: 1, 8344: 1, 8343: 1, 8191: 1, 8190: 1, 8188: 1, 8171: 1, 8157: 1, 8130: 1, 8126: 1, 8104: 1, 8058: 1, 8044: 1, 8032: 1, 8002: 1, 7992: 1, 7942: 1, 7923: 1, 7918: 1, 7909: 1, 7893: 1, 7887: 1, 7844: 1, 7838: 1, 7834: 1, 7827: 1, 7825: 1, 7809: 1, 7745: 1, 7708: 1, 7691: 1, 7690: 1, 7673: 1, 7640: 1, 7615: 1, 7593: 1, 7578: 1, 7575: 1, 7571: 1, 7566: 1, 7529: 1, 7515: 1, 7497: 1, 7496: 1, 7476: 1, 7446: 1, 7441: 1, 7422: 1, 7404: 1, 7373: 1, 7367: 1, 7365: 1, 7364: 1, 7349: 1, 7346: 1, 7337: 1, 7281: 1, 7249: 1, 7243: 1, 7230: 1, 7215: 1, 7190: 1, 7181: 1, 7177: 1, 7145: 1, 7144: 1, 7129: 1, 7111: 1, 7108: 1, 7102: 1, 7094: 1, 7080: 1, 7078: 1, 7077: 1, 7071: 1, 7067: 1, 7022: 1, 7017: 1, 7012: 1, 6968: 1, 6964: 1, 6963: 1, 6953: 1, 6952: 1, 6932: 1, 6921: 1, 6912: 1, 6897: 1, 6887: 1, 6858: 1, 6855: 1, 6804: 1, 6787: 1, 6786: 1, 6766: 1, 6747: 1, 6731: 1, 6712: 1, 6711: 1, 6710: 1, 6686: 1, 6682: 1, 6676: 1, 6 ...

# %%
# Train a Logistic regression+Calibration model using text features whicha re on-hot encoded
alpha = [10 ** x for x in range(-5, 1)]

# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------


cv_log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_text_feature_onehotCoding, y_train)
    
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_text_feature_onehotCoding, y_train)
    predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
    cv_log_error_array.append(log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_text_feature_onehotCoding, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_text_feature_onehotCoding, y_train)

predict_y = sig_clf.predict_proba(train_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_text_feature_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# For values of alpha =  1e-05 The log loss is: 1.1030465470722022
# For values of alpha =  0.0001 The log loss is: 1.1065625465218214
# For values of alpha =  0.001 The log loss is: 1.3285151386698306
# For values of alpha =  0.01 The log loss is: 1.5382653520636853
# For values of alpha =  0.1 The log loss is: 1.800016237065845
# For values of alpha =  1 The log loss is: 1.8243845608186324
# For values of best alpha =  1e-05 The train log loss is: 0.8147439050134494
# For values of best alpha =  1e-05 The cross validation log loss is: 1.1030465470722022
# For values of best alpha =  1e-05 The test log loss is: 1.0934878454972532

# %% [markdown]
# <p style="font-size:18px;"> <b>Q.</b> Is the Text feature stable across all the data sets (Test, Train, Cross validation)?</p>
# <p style="font-size:16px;"> <b>Ans.</b> Yes, it seems like! </p>

# %%
def get_intersec_text(df):
    df_text_vec = CountVectorizer(min_df=3,ngram_range=(1,2), max_features=1000)
    df_text_fea = df_text_vec.fit_transform(df['TEXT'])
    df_text_features = df_text_vec.get_feature_names()

    df_text_fea_counts = df_text_fea.sum(axis=0).A1
    df_text_fea_dict = dict(zip(list(df_text_features),df_text_fea_counts))
    len1 = len(set(df_text_features))
    len2 = len(set(train_text_features) & set(df_text_features))
    return len1,len2

# %%
len1,len2 = get_intersec_text(test_df)
print(np.round((len2/len1)*100, 3), "% of word of test data appeared in train data")
len1,len2 = get_intersec_text(cv_df)
print(np.round((len2/len1)*100, 3), "% of word of Cross Validation appeared in train data")
# Out:
# 94.8 % of word of test data appeared in train data
# 93.7 % of word of Cross Validation appeared in train data

# %% [markdown]
# <h1>4. Machine Learning Models</h1>

# %%
#Data preparation for ML models.

#Misc. functionns for ML models


def predict_and_plot_confusion_matrix(train_x, train_y,test_x, test_y, clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    pred_y = sig_clf.predict(test_x)

    # for calculating log_loss we willl provide the array of probabilities belongs to each class
    print("Log loss :",log_loss(test_y, sig_clf.predict_proba(test_x)))
    # calculating the number of data points that are misclassified
    print("Number of mis-classified points :", np.count_nonzero((pred_y- test_y))/test_y.shape[0])
    plot_confusion_matrix(test_y, pred_y)

# %%
def report_log_loss(train_x, train_y, test_x, test_y,  clf):
    clf.fit(train_x, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x, train_y)
    sig_clf_probs = sig_clf.predict_proba(test_x)
    return log_loss(test_y, sig_clf_probs, eps=1e-15)

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(min_df=5,ngram_range=(1,2), max_features=1000)
    var_count_vec = CountVectorizer(min_df=5,ngram_range=(1,2), max_features=1000)
    text_count_vec = CountVectorizer(min_df=3,ngram_range=(1,2), max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %% [markdown]
# <p style="font-size:24px;text-align:Center"> <b>Stacking the three types of features </b><p>

# %%
"""
train_gene_freq
cv_gene_freq
test_gene_freq

train_var_freq
cv_var_freq
test_var_freq

train_text_len
cv_text_len
test_text_len
"""
# Out:
# '\ntrain_gene_freq\ncv_gene_freq\ntest_gene_freq\n\ntrain_var_freq\ncv_var_freq\ntest_var_freq\n\ntrain_text_len\ncv_text_len\ntest_text_len\n'

# %%
# merging gene, variance and text features

# building train, test and cross validation data sets
# a = [[1, 2], 
#      [3, 4]]
# b = [[4, 5], 
#      [6, 7]]
# hstack(a, b) = [[1, 2, 4, 5],
#                [ 3, 4, 6, 7]]

train_gene_var_onehotCoding = hstack((train_gene_feature_onehotCoding,train_variation_feature_onehotCoding))
test_gene_var_onehotCoding = hstack((test_gene_feature_onehotCoding,test_variation_feature_onehotCoding))
cv_gene_var_onehotCoding = hstack((cv_gene_feature_onehotCoding,cv_variation_feature_onehotCoding))

train_x_onehotCoding = hstack((train_gene_freq, train_var_freq, train_text_len,train_gene_var_onehotCoding, train_text_feature_onehotCoding)).tocsr()
train_y = np.array(list(train_df['Class']))

test_x_onehotCoding = hstack((test_gene_freq, test_var_freq, test_text_len, test_gene_var_onehotCoding, test_text_feature_onehotCoding)).tocsr()
test_y = np.array(list(test_df['Class']))

cv_x_onehotCoding = hstack((cv_gene_freq, cv_var_freq, cv_text_len, cv_gene_var_onehotCoding, cv_text_feature_onehotCoding)).tocsr()
cv_y = np.array(list(cv_df['Class']))

# %%
print("One hot encoding features :")
print("(number of data points * number of features) in train data = ", train_x_onehotCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_onehotCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_onehotCoding.shape)
# Out:
# One hot encoding features :
# (number of data points * number of features) in train data =  (2124, 1065)
# (number of data points * number of features) in test data =  (665, 1065)
# (number of data points * number of features) in cross validation data = (532, 1065)

# %%
train_gene_var_responseCoding = np.hstack((train_gene_feature_responseCoding,train_variation_feature_responseCoding))
test_gene_var_responseCoding = np.hstack((test_gene_feature_responseCoding,test_variation_feature_responseCoding))
cv_gene_var_responseCoding = np.hstack((cv_gene_feature_responseCoding,cv_variation_feature_responseCoding))

train_x_responseCoding = np.hstack((train_gene_freq, train_var_freq, train_text_len,train_gene_var_responseCoding, train_text_feature_responseCoding))
test_x_responseCoding = np.hstack((test_gene_freq, test_var_freq, test_text_len,test_gene_var_responseCoding, test_text_feature_responseCoding))
cv_x_responseCoding = np.hstack((cv_gene_freq, cv_var_freq, cv_text_len, cv_gene_var_responseCoding, cv_text_feature_responseCoding))

# %%
print(" Response encoding features :")
print("(number of data points * number of features) in train data = ", train_x_responseCoding.shape)
print("(number of data points * number of features) in test data = ", test_x_responseCoding.shape)
print("(number of data points * number of features) in cross validation data =", cv_x_responseCoding.shape)
# Out:
#  Response encoding features :
# (number of data points * number of features) in train data =  (2124, 30)
# (number of data points * number of features) in test data =  (665, 30)
# (number of data points * number of features) in cross validation data = (532, 30)

# %% [markdown]
# <h2>4.1. Base Line Model</h2>

# %% [markdown]
# <h3>4.1.1. Naive Bayes</h3>

# %% [markdown]
# <h4>4.1.1.1. Hyper parameter tuning</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


alpha = [0.00001, 0.0001, 0.001, 0.1, 1, 10, 100,1000]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = MultinomialNB(alpha=i)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(np.log10(alpha), cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (np.log10(alpha[i]),cv_log_error_array[i]))
plt.grid()
plt.xticks(np.log10(alpha))
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)


predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-05
# Log Loss : 1.1516811747169253
# for alpha = 0.0001
# Log Loss : 1.1512818004374812
# for alpha = 0.001
# Log Loss : 1.1510006368368784
# for alpha = 0.1
# Log Loss : 1.1468558714188524
# for alpha = 1
# Log Loss : 1.1583176890078317
# for alpha = 10
# Log Loss : 1.254831685032296
# for alpha = 100
# Log Loss : 1.3271766903882565
# for alpha = 1000
# Log Loss : 1.3091411650902425
# For values of best alpha =  0.1 The train log loss is: 1.1336313733072607
# For values of best alpha =  0.1 The cross validation log loss is: 1.1468558714188524
# For values of best alpha =  0.1 The test log loss is: 1.20486909209489

# %% [markdown]
# <h4>4.1.1.2. Testing the model with best hyper paramters</h4>

# %%
# find more about Multinomial Naive base function here http://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.MultinomialNB.html
# -------------------------
# default paramters
# sklearn.naive_bayes.MultinomialNB(alpha=1.0, fit_prior=True, class_prior=None)

# some of methods of MultinomialNB()
# fit(X, y[, sample_weight])	Fit Naive Bayes classifier according to X, y
# predict(X)	Perform classification on an array of test vectors X.
# predict_log_proba(X)	Return log-probability estimates for the test vector X.
# -----------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/naive-bayes-algorithm-1/
# -----------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
# ----------------------------

clf = MultinomialNB(alpha=alpha[best_alpha])
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)
sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
# to avoid rounding error while multiplying probabilites we use log-probability estimates
print("Log Loss :",log_loss(cv_y, sig_clf_probs))
print("Number of missclassified point :", np.count_nonzero((sig_clf.predict(cv_x_onehotCoding)- cv_y))/cv_y.shape[0])
plot_confusion_matrix(cv_y, sig_clf.predict(cv_x_onehotCoding.toarray()))
# Out:
# Log Loss : 1.1468558714188524
# Number of missclassified point : 0.37593984962406013
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.1.1.3. Feature Importance, Correctly classified point</h4>

# %%
test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices=np.argsort(-1*clf.coef_)[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.7714 0.0417 0.0143 0.0521 0.0366 0.0346 0.0374 0.0057 0.0062]]
# Actual Class : 1
# --------------------------------------------------
# 20 Text feature [expressing] present in test data point [True]
# 22 Text feature [42] present in test data point [True]
# 23 Text feature [tumor] present in test data point [True]
# 24 Text feature [chain] present in test data point [True]
# 26 Text feature [ii] present in test data point [True]
# 28 Text feature [80] present in test data point [True]
# 29 Text feature [also] present in test data point [True]
# 30 Text feature [acid] present in test data point [True]
# 33 Text feature [see] present in test data point [True]
# 34 Text feature [time] present in test data point [True]
# 35 Text feature [30] present in test data point [True]
# 36 Text feature [exon] present in test data point [True]
# 37 Text feature [95] present in test data point [True]
# 38 Text feature [evidence] present in test data point [True]
# 42 Text feature [s3] present in test data point [True]
# 43 Text feature [compared] present in test data point [True]
# 45 Text feature [involving] present in test data point [True]
# 46 Text feature [induce] present in test data point [True]
# 47 Text feature [overall] present in test data point [True]
# 48 Text feature [taken] present in test data point [True]
# 49 Text feature [established] present in test data point [True]
# 50 Text feature [structural] present in test data point [True]
# 51 Text feature [splice] present in test data point [True]
# 54 Text feature [structure] present in test data point [True]
# 56 Text feature [presence] present in test data point [True]
# 59 Text feature [rather] present in test data point [True]
# 61 Text feature [controls] present in test data point [True]
# 62 Text feature [gfp] present in test data point [True]
# 64 Text feature [downstream] present in test data point [True]
# 65 Text feature [ras] present in test data point [True]
# 66 Text feature [potential] present in test data point [True]
# 68 Text feature [full] present in test data point [True]
# 71 Text feature [60] present in test data point [True]
# 73 Text feature [significance] present in test data point [True]
# 75 Text feature [investigated] present in test data point [True]
# 76 Text feature [selected] present in test data point [True]
# 79 Text feature [deletion] present in test data point [True]
# 85 Text feature [interaction] present in test data point [True]
# 86 Text feature [co] present in test data point [True]
# 87 Text feature [leading] present in test data point [True]
# 89 Text feature [40] present in test data point [True]
# 90 Text feature [generated] present in test data point [True]
# 91 Text feature [risk] present in test data point [True]
# 96 Text feature [despite] present in test data point [True]
# 98 Text feature [kd] present in test data point [True]
# Out of the top  100  features  45 are present in query point

# %%
test_df['TEXT'].iloc[test_point_index]
# Out:
# 'asxl1 frequently mutated spectrum myeloid malignancies poor prognosis loss asxl1 leads myelodysplastic syndrome like disease mice however underlying molecular mechanisms remain unclear report asxl1 interacts cohesin complex shown guide sister chromatid segregation regulate gene expression loss asxl1 impairs cohesin function reflected impaired telophase chromatid disjunction hematopoietic cells chromatin immunoprecipitation followed dna sequencing data revealed asxl1 rad21 smc1a share 93 genomic binding sites promoter regions lin ckit lk cells shown loss asxl1 reduces genome binding rad21 smc1a alters expression asxl1 cohesin target genes lk cells study underscores asxl1 cohesin interaction novel means maintain normal sister chromatid separation regulate gene expression hematopoietic cells keywords asxl1 cohesin complex hematopoiesis gene regulation go introduction asxl1 additional sex combs like 1 gene mutations frequently occur spectrum myeloid malignancies including myelodysplastic syndrome mds chronic myelomonocytic leukemia cmml myeloproliferative neoplasms mpns acute myeloid leukemia aml 1 4 asxl1 mutation poor prognostic marker mds cmml aml 5 7 suggesting important role asxl1 mutations disease initiation progression asxl1 gene encodes asxl1 one polycomb group proteins proteins necessary maintenance stable repression homeotic genes gene loci 8 10 others reported loss asxl1 leads development mds like diseases mice progress bone marrow bm failure mpn 11 12 asxl1 also shown regulate self renewal differentiation mesenchymal stromal cells erythropoiesis 13 14 addition loss asxl1 hematopoietic stem cells hscs hematopoietic progenitor cells hpcs reduces global levels histone h3 lysine 27 trimethylation h3k27me3 h3k4me3 alters expression genes implicated apoptosis 11 cohesin multiple subunit protein complex highly conserved mammalian cells 15 cohesin complex consists four major subunits rad21 smc1a smc3 stag1 stag2 16 17 core cohesin proteins form triangular ring embraces sister chromatids prevents premature separation 18 19 besides major function sister chromatid cohesion cohesin complex participates many cellular processes transcriptional regulation long range cis interactions 20 26 recently clinical studies discovered recurrent mutations deletions cohesin genes variety myeloid malignancies including mds aml cmml chronic myelogenous leukemia 16 27 28 furthermore cohesin mutations occur mutually exclusive manner 16 29 30 recent study merkenschlager odom 31 suggests cohesin associates enhancers promoters sites defined ctcf ccctc binding factor binding form regulated networks long range interactions promote cell type specific transcriptional programs report asxl1 interacts core proteins cohesin complex chromatin immunoprecipitation followed dna sequencing chip seq analysis revealed significant overlap asxl1 rad21 smc1a binding sites genome mainly located promoter regions genes loss asxl1 decreased rad21 smc1a occupancy genome altered expression target genes deletion asxl1 results significantly higher frequency impaired telophase chromatid disjunction hematopoietic cells congruent previous finding az mart nez et al 32 silencing rad21 leads nuclear bridging hela cells collectively data demonstrate novel biological function asxl1 transcriptional regulation via interaction cohesin complex proteins addition maintenance normal chromatid separation findings provide strong evidence asxl1 essential maintenance gene expression preventing dysplastic morphology formation via cohesin complex hsc hpcs go results asxl1 interacts cohesin complex proteins located nucleus capable regulating gene expression asxl1 exert function concert interacting partners identify functional asxl1 interacting proteins performed protein affinity purification using anti flag antibody fig s1a nuclear extracts prepared human embryonic kidney hek 293t cells engineered overexpress flag tagged asxl1 fig s1b asxl1 interacting proteins identified liquid chromatography tand ...

# %%
no_feature
# Out:
# 100

# %%
test_df['Gene'].iloc[test_point_index]
# Out:
# 'RAD21'

# %%
test_df['Variation'].iloc[test_point_index]
# Out:
# 'Truncating_Mutations'

# %%
clf.coef_.shape
# Out:
# (9, 1065)

# %%
indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
indices[0]
# Out:
# array([  23,   24,   25,   26,   27,   28,   29,   33,   34,   36,   63,
#          39,   62,   60,   57,   53,   49,   22,   47,    3,    5,   16,
#          15,    7,   13,   12,   18,   10,    4,  503,  502,  263,  584,
#         334,  173,  178,  443,  405,  419,  219,  654,  417,  218,  755,
#         542,  490,  659,  452,  148,  433,  454,  596,  442,  754,  397,
#         341,  705,  432,  451,  466,  340,  223,  806,  237,  518,  710,
#         404,  122,  487,  711,  736,  205,  592,  653,  927,  767,  933,
#         656,  994,  403,  925,  695,  809,  714,  684, 1047,  856,  514,
#         802,  416, 1025,  534,  264,  716,  738,  172,  418,  339,  389,
#         766])

# %%
# this function will be used just for naive bayes
# for the given indices, we will print the name of the features
# and we will check whether the feature present in the test point text or not
def get_impfeature_names(indices, text, gene, var, no_features):
    gene_count_vec = CountVectorizer(min_df=5,ngram_range=(1,2), max_features=1000)
    var_count_vec = CountVectorizer(min_df=5,ngram_range=(1,2), max_features=1000)
    text_count_vec = CountVectorizer(min_df=3,ngram_range=(1,2), max_features=1000)
    
    gene_vec = gene_count_vec.fit(train_df['Gene'])
    var_vec  = var_count_vec.fit(train_df['Variation'])
    text_vec = text_count_vec.fit(train_df['TEXT'])
    
    fea1_len = len(gene_vec.get_feature_names())
    fea2_len = len(var_count_vec.get_feature_names())
    
    word_present = 0
    for i,v in enumerate(indices):
        if (v < fea1_len):
            word = gene_vec.get_feature_names()[v]
            yes_no = True if word == gene else False
            if yes_no:
                word_present += 1
                print(i, "Gene feature [{}] present in test data point [{}]".format(word,yes_no))
        elif (v < fea1_len+fea2_len):
            word = var_vec.get_feature_names()[v-(fea1_len)]
            yes_no = True if word == var else False
            if yes_no:
                word_present += 1
                print(i, "variation feature [{}] present in test data point [{}]".format(word,yes_no))
        else:
            word = text_vec.get_feature_names()[v-(fea1_len+fea2_len)]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
                print(i, "Text feature [{}] present in test data point [{}]".format(word,yes_no))

    print("Out of the top ",no_features," features ", word_present, "are present in query point")

# %%
"""for i in range(10):
    test_point_index = i
    no_feature = 100
    predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
    print("Predicted Class :", predicted_cls[0])
    print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
    print("Actual Class :", test_y[test_point_index])
    indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:]
    print("-"*50)
    get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index].lower(),test_df['Variation'].iloc[test_point_index], no_feature)"""
# Out:
# 'for i in range(10):\n    test_point_index = i\n    no_feature = 100\n    predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])\n    print("Predicted Class :", predicted_cls[0])\n    print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))\n    print("Actual Class :", test_y[test_point_index])\n    indices=np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:]\n    print("-"*50)\n    get_impfeature_names(indices[0], test_df[\'TEXT\'].iloc[test_point_index],test_df[\'Gene\'].iloc[test_point_index].lower(),test_df[\'Variation\'].iloc[test_point_index], no_feature)'

# %% [markdown]
# <h4>4.1.1.4. Feature Importance, Incorrectly classified point</h4>

# %%
test_point_index = 100
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 7
# Predicted Class Probabilities: [[0.0522 0.3863 0.0157 0.0563 0.0401 0.037  0.3995 0.0062 0.0067]]
# Actual Class : 7
# --------------------------------------------------
# 14 Text feature [transfection] present in test data point [True]
# 26 Text feature [anti] present in test data point [True]
# 27 Text feature [antibody] present in test data point [True]
# 29 Text feature [sequence] present in test data point [True]
# 30 Text feature [samples] present in test data point [True]
# 31 Text feature [lower] present in test data point [True]
# 32 Text feature [screening] present in test data point [True]
# 33 Text feature [sd] present in test data point [True]
# 34 Text feature [phosphatase] present in test data point [True]
# 36 Text feature [antibodies] present in test data point [True]
# 37 Text feature [analyzed] present in test data point [True]
# 40 Text feature [another] present in test data point [True]
# 41 Text feature [lung] present in test data point [True]
# 42 Text feature [frequency] present in test data point [True]
# 43 Text feature [system] present in test data point [True]
# 44 Text feature [considered] present in test data point [True]
# 45 Text feature [analysis] present in test data point [True]
# 47 Text feature [syndrome] present in test data point [True]
# 50 Text feature [melanomas] present in test data point [True]
# 52 Text feature [basal] present in test data point [True]
# 53 Text feature [nature] present in test data point [True]
# 54 Text feature [nih] present in test data point [True]
# 55 Text feature [two] present in test data point [True]
# 59 Text feature [functional] present in test data point [True]
# 61 Text feature [receptor] present in test data point [True]
# 62 Text feature [progression] present in test data point [True]
# 63 Text feature [insertion] present in test data point [True]
# 67 Text feature [egfr] present in test data point [True]
# 68 Text feature [suggest] present in test data point [True]
# 70 Text feature [sensitivity] present in test data point [True]
# 71 Text feature [akt] present in test data point [True]
# 72 Text feature [tkis] present in test data point [True]
# 74 Text feature [molecular] present in test data point [True]
# 76 Text feature [mutation] present in test data point [True]
# 79 Text feature [activities] present in test data point [True]
# 80 Text feature [suggested] present in test data point [True]
# 82 Text feature [lack] present in test data point [True]
# 83 Text feature [detection] present in test data point [True]
# 84 Text feature [classification] present in test data point [True]
# 85 Text feature [sites] present in test data point [True]
# 86 Text feature [negative] present in test data point [True]
# 88 Text feature [conditions] present in test data point [True]
# 89 Text feature [proliferation] present in test data point [True]
# 90 Text feature [common] present in test data point [True]
# 91 Text feature [isolated] present in test data point [True]
# 92 Text feature [fusion] present in test data point [True]
# 95 Text feature [loop] present in test data point [True]
# 99 Text feature [confirmed] present in test data point [True]
# Out of the top  100  features  48 are present in query point

# %% [markdown]
# <h2>4.2. K Nearest Neighbour Classification</h2>

# %% [markdown]
# <h3>4.2.1. Hyper parameter tuning</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------


alpha = [5, 11, 15, 21, 31, 41, 51, 99]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = KNeighborsClassifier(n_neighbors=i)
    clf.fit(train_x_responseCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_responseCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 5
# Log Loss : 1.0911308869669798
# for alpha = 11
# Log Loss : 1.0488733521447697
# for alpha = 15
# Log Loss : 1.0473219750755385
# for alpha = 21
# Log Loss : 1.054532119381993
# for alpha = 31
# Log Loss : 1.0572401126128912
# for alpha = 41
# Log Loss : 1.0565090169753046
# for alpha = 51
# Log Loss : 1.0665314513944497
# for alpha = 99
# Log Loss : 1.0712377886093956
# For values of best alpha =  15 The train log loss is: 0.6640296612216108
# For values of best alpha =  15 The cross validation log loss is: 1.0473219750755385
# For values of best alpha =  15 The test log loss is: 1.0037034292642386

# %% [markdown]
# <h3>4.2.2. Testing the model with best hyper paramters</h3>

# %%
# find more about KNeighborsClassifier() here http://scikit-learn.org/stable/modules/generated/sklearn.neighbors.KNeighborsClassifier.html
# -------------------------
# default parameter
# KNeighborsClassifier(n_neighbors=5, weights=’uniform’, algorithm=’auto’, leaf_size=30, p=2, 
# metric=’minkowski’, metric_params=None, n_jobs=1, **kwargs)

# methods of
# fit(X, y) : Fit the model using X as training data and y as target values
# predict(X):Predict the class labels for the provided data
# predict_proba(X):Return probability estimates for the test data X.
#-------------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/k-nearest-neighbors-geometric-intuition-with-a-toy-example-1/
#-------------------------------------
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y, cv_x_responseCoding, cv_y, clf)
# Out:
# Log loss : 1.0473219750755385
# Number of mis-classified points : 0.36654135338345867
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.2.3.Sample Query point -1</h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 1
predicted_cls = sig_clf.predict(test_x_responseCoding[0].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("The ",alpha[best_alpha]," nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 4
# Actual Class : 1
# The  15  nearest neighbours of the test points belongs to classes [1 1 1 1 1 1 6 1 1 1 1 1 1 1 1]
# Fequency of nearest points : Counter({1: 14, 6: 1})

# %% [markdown]
# <h3>4.2.4. Sample Query Point-2 </h3>

# %%
clf = KNeighborsClassifier(n_neighbors=alpha[best_alpha])
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

test_point_index = 100

predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Actual Class :", test_y[test_point_index])
neighbors = clf.kneighbors(test_x_responseCoding[test_point_index].reshape(1, -1), alpha[best_alpha])
print("the k value for knn is",alpha[best_alpha],"and the nearest neighbours of the test points belongs to classes",train_y[neighbors[1][0]])
print("Fequency of nearest points :",Counter(train_y[neighbors[1][0]]))
# Out:
# Predicted Class : 7
# Actual Class : 7
# the k value for knn is 15 and the nearest neighbours of the test points belongs to classes [7 7 7 2 7 2 7 7 7 2 2 7 2 7 2]
# Fequency of nearest points : Counter({7: 9, 2: 6})

# %% [markdown]
# <h2>4.3. Logistic Regression</h2>

# %% [markdown]
# <h3>4.3.1. With Class balancing</h3>

# %% [markdown]
# <h4>4.3.1.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 3)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(class_weight='balanced', alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    # to avoid rounding error while multiplying probabilites we use log-probability estimates
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.060195692665539
# for alpha = 1e-05
# Log Loss : 1.042717408446571
# for alpha = 0.0001
# Log Loss : 0.9875199755720065
# for alpha = 0.001
# Log Loss : 1.0589570857633588
# for alpha = 0.01
# Log Loss : 1.1902198452551829
# for alpha = 0.1
# Log Loss : 1.265416834307608
# for alpha = 1
# Log Loss : 1.6718421012161442
# for alpha = 10
# Log Loss : 1.7630062269146718
# for alpha = 100
# Log Loss : 1.7704974731028538
# For values of best alpha =  0.0001 The train log loss is: 0.8396937321854453
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9875199755720065
# For values of best alpha =  0.0001 The test log loss is: 1.020525909954082

# %% [markdown]
# <h4>4.3.1.2. Testing the model with best hyper paramters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9875199755720065
# Number of mis-classified points : 0.34022556390977443
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.1.3. Feature Importance</h4>

# %%
def get_imp_feature_names(text, indices, removed_ind = []):
    word_present = 0
    tabulte_list = []
    incresingorder_ind = 0
    for i in indices:
        if i < train_gene_feature_onehotCoding.shape[1]:
            tabulte_list.append([incresingorder_ind, "Gene", "Yes"])
        elif i< 18:
            tabulte_list.append([incresingorder_ind,"Variation", "Yes"])
        if ((i > 17) & (i not in removed_ind)) :
            word = train_text_features[i]
            yes_no = True if word in text.split() else False
            if yes_no:
                word_present += 1
            tabulte_list.append([incresingorder_ind,train_text_features[i], yes_no])
        incresingorder_ind += 1
    print(word_present, "most importent features are present in our query point")
    print("-"*50)
    print("The features that are most importent of the ",predicted_cls[0]," class:")
    print (tabulate(tabulte_list, headers=["Index",'Feature name', 'Present or Not']))

# %% [markdown]
# <h5>4.3.1.3.1. Correctly Classified point</h5>

# %%
# from tabulate import tabulate
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.9097 0.04   0.0022 0.0072 0.0056 0.0208 0.0091 0.004  0.0015]]
# Actual Class : 1
# --------------------------------------------------
# 2 Text feature [splice] present in test data point [True]
# 5 Text feature [confirmed] present in test data point [True]
# 9 Text feature [determine] present in test data point [True]
# 12 Text feature [functional] present in test data point [True]
# 13 Text feature [test] present in test data point [True]
# 14 Text feature [proliferation] present in test data point [True]
# 27 Text feature [antibodies] present in test data point [True]
# 30 Text feature [receptor] present in test data point [True]
# 34 Text feature [analyzed] present in test data point [True]
# 41 Text feature [selected] present in test data point [True]
# 44 Text feature [degradation] present in test data point [True]
# 47 Text feature [19] present in test data point [True]
# 48 Text feature [mechanism] present in test data point [True]
# 49 Text feature [novel] present in test data point [True]
# 52 Text feature [cells] present in test data point [True]
# 56 Text feature [driven] present in test data point [True]
# 57 Text feature [majority] present in test data point [True]
# 62 Text feature [development] present in test data point [True]
# 65 Text feature [suppression] present in test data point [True]
# 67 Text feature [pathogenic] present in test data point [True]
# 68 Text feature [taken] present in test data point [True]
# 69 Text feature [considered] present in test data point [True]
# 70 Text feature [recently] present in test data point [True]
# 71 Text feature [significance] present in test data point [True]
# 76 Text feature [family] present in test data point [True]
# 79 Text feature [shown] present in test data point [True]
# 81 Text feature [two] present in test data point [True]
# 83 Text feature [represent] present in test data point [True]
# 84 Text feature [il] present in test data point [True]
# 86 Text feature [together] present in test data point [True]
# 89 Text feature [function] present in test data point [True]
# 91 Text feature [showed] present in test data point [True]
# 94 Text feature [diagnosis] present in test data point [True]
# 95 Text feature [samples] present in test data point [True]
# 96 Text feature [nih] present in test data point [True]
# 99 Text feature [34] present in test data point [True]
# 100 Text feature [multiple] present in test data point [True]
# 101 Text feature [analysis] present in test data point [True]
# 102 Text feature [binding] present in test data point [True]
# 103 Text feature [factor] present in test data point [True]
# 112 Text feature [reduced] present in test data point [True]
# 114 Text feature [efficacy] present in test data point [True]
# 115 Text feature [lymphoma] present in test data point [True]
# 116 Text feature [factors] present in test data point [True]
# 118 Text feature [cases] present in test data point [True]
# 120 Text feature [knockdown] present in test data point [True]
# 122 Text feature [patients] present in test data point [True]
# 123 Text feature [generated] present in test data point [True]
# 124 Text feature [suggest] present in test data point [True]
# 125 Text feature [mouse] present in test data point [True]
# 126 Text feature [detected] present in test data point [True]
# 128 Text feature [harboring] present in test data point [True]
# 129 Text feature [based] present in test data point [True]
# 132 Text feature [expected] present in test data point [True]
# 137 Text feature [show] present in test data point [True]
# 141 Text feature [aml] present in test data point [True]
# 143 Text feature [resulted] present in test data point [True]
# 146 Text feature [part] present in test data point [True]
# 147 Text feature [methods] present in test data point [True]
# 148 Text feature [cellular] present in test data point [True]
# 155 Text feature [clones] present in test data point [True]
# 157 Text feature [complex] present in test data point [True]
# 159 Text feature [essential] present in test data point [True]
# 162 Text feature [key] present in test data point [True]
# 165 Text feature [regulatory] present in test data point [True]
# 168 Text feature [several] present in test data point [True]
# 170 Text feature [effects] present in test data point [True]
# 171 Text feature [single] present in test data point [True]
# 175 Text feature [ca] present in test data point [True]
# 176 Text feature [recent] present in test data point [True]
# 177 Text feature [35] present in test data point [True]
# 178 Text feature [available] present in test data point [True]
# 183 Text feature [28] present in test data point [True]
# 185 Text feature [figure] present in test data point [True]
# 187 Text feature [transcriptional] present in test data point [True]
# 188 Text feature [29] present in test data point [True]
# 190 Text feature [also] present in test data point [True]
# 191 Text feature [may] present in test data point [True]
# 192 Text feature [observed] present in test data point [True]
# 195 Text feature [phase] present in test data point [True]
# 196 Text feature [human] present in test data point [True]
# 199 Text feature [lead] present in test data point [True]
# 200 Text feature [chromosome] present in test data point [True]
# 201 Text feature [ii] present in test data point [True]
# 203 Text feature [tumors] present in test data point [True]
# 204 Text feature [common] present in test data point [True]
# 207 Text feature [investigated] present in test data point [True]
# 208 Text feature [consistent] present in test data point [True]
# 211 Text feature [alleles] present in test data point [True]
# 212 Text feature [containing] present in test data point [True]
# 213 Text feature [pattern] present in test data point [True]
# 214 Text feature [26] present in test data point [True]
# 217 Text feature [known] present in test data point [True]
# 222 Text feature [expressed] present in test data point [True]
# 224 Text feature [mrna] present in test data point [True]
# 225 Text feature [interactions] present in test data point [True]
# 228 Text feature [resulting] present in test data point [True]
# 230 Text feature [alterations] present in test data point [True]
# 231 Text feature [4a] present in test data point [True]
# 232 Text feature [studied] present in test data point [True]
# 233 Text feature [progression] present in test data point [True]
# 239 Text feature [cdna] present in test data point [True]
# 245 Text feature [fold] present in test data point [True]
# 248 Text feature [nucleotide] present in test data point [True]
# 249 Text feature [deletions] present in test data point [True]
# 250 Text feature [population] present in test data point [True]
# 254 Text feature [s3] present in test data point [True]
# 256 Text feature [36] present in test data point [True]
# 257 Text feature [involved] present in test data point [True]
# 260 Text feature [established] present in test data point [True]
# 262 Text feature [genetic] present in test data point [True]
# 263 Text feature [next] present in test data point [True]
# 264 Text feature [normal] present in test data point [True]
# 266 Text feature [42] present in test data point [True]
# 267 Text feature [therapy] present in test data point [True]
# 269 Text feature [200] present in test data point [True]
# 273 Text feature [pathway] present in test data point [True]
# 275 Text feature [blood] present in test data point [True]
# 277 Text feature [nras] present in test data point [True]
# 278 Text feature [small] present in test data point [True]
# 281 Text feature [41] present in test data point [True]
# 284 Text feature [type] present in test data point [True]
# 285 Text feature [allele] present in test data point [True]
# 286 Text feature [number] present in test data point [True]
# 287 Text feature [cbl] present in test data point [True]
# 289 Text feature [heterozygous] present in test data point [True]
# 290 Text feature [manner] present in test data point [True]
# 291 Text feature [differences] present in test data point [True]
# 294 Text feature [16] present in test data point [True]
# 296 Text feature [sample] present in test data point [True]
# 299 Text feature [tumor] present in test data point [True]
# 303 Text feature [expression] present in test data point [True]
# 305 Text feature [mean] present in test data point [True]
# 307 Text feature [strong] present in test data point [True]
# 311 Text feature [cause] present in test data point [True]
# 313 Text feature [cancer] present in test data point [True]
# 316 Text feature [locus] present in test data point [True]
# 317 Text feature [decreased] present in test data point [True]
# 318 Text feature [dominant] present in test data point [True]
# 321 Text feature [defects] present in test data point [True]
# 322 Text feature [comparison] present in test data point [True]
# 324 Text feature [induced] present in test data point [True]
# 325 Text feature [activating] present in test data point [True]
# 326 Text feature [tet2] present in test data point [True]
# 328 Text feature [important] present in test data point [True]
# 329 Text feature [average] present in test data point [True]
# 332 Text feature [46] present in test data point [True]
# 333 Text feature [related] present in test data point [True]
# 334 Text feature [different] present in test data point [True]
# 337 Text feature [report] present in test data point [True]
# 338 Text feature [domain] present in test data point [True]
# 340 Text feature [lower] present in test data point [True]
# 341 Text feature [critical] present in test data point [True]
# 342 Text feature [rna] present in test data point [True]
# 345 Text feature [expressing] present in test data point [True]
# 346 Text feature [activated] present in test data point [True]
# 349 Text feature [reduction] present in test data point [True]
# 351 Text feature [primary] present in test data point [True]
# 356 Text feature [line] present in test data point [True]
# 357 Text feature [primers] present in test data point [True]
# 358 Text feature [partial] present in test data point [True]
# 359 Text feature [95] present in test data point [True]
# 361 Text feature [four] present in test data point [True]
# 362 Text feature [13] present in test data point [True]
# 363 Text feature [absence] present in test data point [True]
# 364 Text feature [performed] present in test data point [True]
# 365 Text feature [2a] present in test data point [True]
# 369 Text feature [31] present in test data point [True]
# 372 Text feature [mediated] present in test data point [True]
# 374 Text feature [30] present in test data point [True]
# 375 Text feature [models] present in test data point [True]
# 376 Text feature [go] present in test data point [True]
# 378 Text feature [amino] present in test data point [True]
# 381 Text feature [mutation] present in test data point [True]
# 382 Text feature [hr] present in test data point [True]
# 389 Text feature [transformation] present in test data point [True]
# 390 Text feature [significant] present in test data point [True]
# 391 Text feature [respectively] present in test data point [True]
# 393 Text feature [top] present in test data point [True]
# 394 Text feature [site] present in test data point [True]
# 395 Text feature [ring] present in test data point [True]
# 398 Text feature [involving] present in test data point [True]
# 399 Text feature [findings] present in test data point [True]
# 401 Text feature [system] present in test data point [True]
# 402 Text feature [inhibitor] present in test data point [True]
# 404 Text feature [proteins] present in test data point [True]
# 405 Text feature [effect] present in test data point [True]
# 406 Text feature [germline] present in test data point [True]
# 408 Text feature [occur] present in test data point [True]
# 410 Text feature [induce] present in test data point [True]
# 412 Text feature [patient] present in test data point [True]
# 414 Text feature [evidence] present in test data point [True]
# 416 Text feature [2000] present in test data point [True]
# 417 Text feature [interaction] present in test data point [True]
# 419 Text feature [23] present in test data point [True]
# 422 Text feature [might] present in test data point [True]
# 423 Text feature [negative] present in test data point [True]
# 424 Text feature [previously] present in test data point [True]
# 425 Text feature [database] present in test data point [True]
# 426 Text feature [nature] present in test data point [True]
# 427 Text feature [org] present in test data point [True]
# 432 Text feature [loss] present in test data point [True]
# 433 Text feature [forms] present in test data point [True]
# 436 Text feature [regulated] present in test data point [True]
# 437 Text feature [first] present in test data point [True]
# 441 Text feature [27] present in test data point [True]
# 444 Text feature [measured] present in test data point [True]
# 447 Text feature [relative] present in test data point [True]
# 449 Text feature [myeloid] present in test data point [True]
# 453 Text feature [47] present in test data point [True]
# 454 Text feature [01] present in test data point [True]
# 455 Text feature [difference] present in test data point [True]
# 457 Text feature [33] present in test data point [True]
# 460 Text feature [increased] present in test data point [True]
# 461 Text feature [high] present in test data point [True]
# 462 Text feature [followed] present in test data point [True]
# 465 Text feature [tagged] present in test data point [True]
# 466 Text feature [conditions] present in test data point [True]
# 467 Text feature [deficient] present in test data point [True]
# 469 Text feature [50] present in test data point [True]
# 470 Text feature [features] present in test data point [True]
# 471 Text feature [highly] present in test data point [True]
# 472 Text feature [specimens] present in test data point [True]
# 474 Text feature [located] present in test data point [True]
# 476 Text feature [transfected] present in test data point [True]
# 477 Text feature [additional] present in test data point [True]
# 482 Text feature [due] present in test data point [True]
# 486 Text feature [three] present in test data point [True]
# 489 Text feature [revealed] present in test data point [True]
# 490 Text feature [survival] present in test data point [True]
# 493 Text feature [control] present in test data point [True]
# 494 Text feature [60] present in test data point [True]
# 496 Text feature [positive] present in test data point [True]
# 497 Text feature [indicates] present in test data point [True]
# 499 Text feature [thus] present in test data point [True]
# Out of the top  500  features  235 are present in query point

# %% [markdown]
# <h3>4.3.2. Without Class balancing</h3>

# %% [markdown]
# <h4>4.3.2.1. Hyper paramter tuning</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-6, 1)]
cv_log_error_array = []
for i in alpha:
    print("for alpha =", i)
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for alpha = 1e-06
# Log Loss : 1.0575869426598414
# for alpha = 1e-05
# Log Loss : 1.0305091805533317
# for alpha = 0.0001
# Log Loss : 0.9834940713290614
# for alpha = 0.001
# Log Loss : 1.0531257753707535
# for alpha = 0.01
# Log Loss : 1.209766951625982
# for alpha = 0.1
# Log Loss : 1.406655115769874
# for alpha = 1
# Log Loss : 1.505838165763615
# For values of best alpha =  0.0001 The train log loss is: 0.8343815557972901
# For values of best alpha =  0.0001 The cross validation log loss is: 0.9834940713290614
# For values of best alpha =  0.0001 The test log loss is: 1.0176962743852147

# %% [markdown]
# <h4>4.3.2.2. Testing model with best hyper parameters</h4>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: 
#------------------------------

clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y, cv_x_onehotCoding, cv_y, clf)
# Out:
# Log loss : 0.9834940713290614
# Number of mis-classified points : 0.32706766917293234
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h4>4.3.2.3. Feature Importance, Correctly Classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.9059 0.0406 0.0031 0.0063 0.0064 0.0215 0.0074 0.0051 0.0037]]
# Actual Class : 1
# --------------------------------------------------
# 1 Text feature [splice] present in test data point [True]
# 3 Text feature [confirmed] present in test data point [True]
# 6 Text feature [determine] present in test data point [True]
# 10 Text feature [test] present in test data point [True]
# 12 Text feature [antibodies] present in test data point [True]
# 13 Text feature [functional] present in test data point [True]
# 16 Text feature [proliferation] present in test data point [True]
# 28 Text feature [receptor] present in test data point [True]
# 29 Text feature [analyzed] present in test data point [True]
# 30 Text feature [selected] present in test data point [True]
# 32 Text feature [majority] present in test data point [True]
# 40 Text feature [19] present in test data point [True]
# 43 Text feature [degradation] present in test data point [True]
# 46 Text feature [cells] present in test data point [True]
# 49 Text feature [mechanism] present in test data point [True]
# 51 Text feature [novel] present in test data point [True]
# 52 Text feature [development] present in test data point [True]
# 53 Text feature [suppression] present in test data point [True]
# 58 Text feature [pathogenic] present in test data point [True]
# 61 Text feature [driven] present in test data point [True]
# 63 Text feature [considered] present in test data point [True]
# 65 Text feature [binding] present in test data point [True]
# 66 Text feature [taken] present in test data point [True]
# 71 Text feature [il] present in test data point [True]
# 72 Text feature [diagnosis] present in test data point [True]
# 77 Text feature [two] present in test data point [True]
# 78 Text feature [significance] present in test data point [True]
# 79 Text feature [represent] present in test data point [True]
# 81 Text feature [factor] present in test data point [True]
# 82 Text feature [together] present in test data point [True]
# 87 Text feature [nih] present in test data point [True]
# 88 Text feature [family] present in test data point [True]
# 91 Text feature [factors] present in test data point [True]
# 92 Text feature [shown] present in test data point [True]
# 95 Text feature [samples] present in test data point [True]
# 98 Text feature [recently] present in test data point [True]
# 100 Text feature [multiple] present in test data point [True]
# 102 Text feature [based] present in test data point [True]
# 103 Text feature [showed] present in test data point [True]
# 105 Text feature [mouse] present in test data point [True]
# 106 Text feature [lymphoma] present in test data point [True]
# 107 Text feature [34] present in test data point [True]
# 111 Text feature [efficacy] present in test data point [True]
# 112 Text feature [suggest] present in test data point [True]
# 114 Text feature [cases] present in test data point [True]
# 117 Text feature [generated] present in test data point [True]
# 118 Text feature [function] present in test data point [True]
# 123 Text feature [resulted] present in test data point [True]
# 127 Text feature [detected] present in test data point [True]
# 129 Text feature [analysis] present in test data point [True]
# 132 Text feature [harboring] present in test data point [True]
# 133 Text feature [key] present in test data point [True]
# 134 Text feature [regulatory] present in test data point [True]
# 135 Text feature [aml] present in test data point [True]
# 136 Text feature [transcriptional] present in test data point [True]
# 137 Text feature [expected] present in test data point [True]
# 138 Text feature [available] present in test data point [True]
# 141 Text feature [cellular] present in test data point [True]
# 142 Text feature [methods] present in test data point [True]
# 143 Text feature [show] present in test data point [True]
# 146 Text feature [reduced] present in test data point [True]
# 147 Text feature [patients] present in test data point [True]
# 148 Text feature [single] present in test data point [True]
# 153 Text feature [effects] present in test data point [True]
# 159 Text feature [ca] present in test data point [True]
# 161 Text feature [observed] present in test data point [True]
# 163 Text feature [figure] present in test data point [True]
# 165 Text feature [chromosome] present in test data point [True]
# 166 Text feature [knockdown] present in test data point [True]
# 169 Text feature [consistent] present in test data point [True]
# 171 Text feature [several] present in test data point [True]
# 173 Text feature [26] present in test data point [True]
# 174 Text feature [essential] present in test data point [True]
# 177 Text feature [29] present in test data point [True]
# 182 Text feature [35] present in test data point [True]
# 185 Text feature [recent] present in test data point [True]
# 186 Text feature [investigated] present in test data point [True]
# 188 Text feature [clones] present in test data point [True]
# 189 Text feature [lead] present in test data point [True]
# 190 Text feature [part] present in test data point [True]
# 194 Text feature [may] present in test data point [True]
# 195 Text feature [containing] present in test data point [True]
# 197 Text feature [cdna] present in test data point [True]
# 198 Text feature [known] present in test data point [True]
# 200 Text feature [phase] present in test data point [True]
# 203 Text feature [28] present in test data point [True]
# 206 Text feature [therapy] present in test data point [True]
# 209 Text feature [type] present in test data point [True]
# 210 Text feature [progression] present in test data point [True]
# 213 Text feature [studied] present in test data point [True]
# 215 Text feature [tumors] present in test data point [True]
# 216 Text feature [complex] present in test data point [True]
# 220 Text feature [alleles] present in test data point [True]
# 223 Text feature [differences] present in test data point [True]
# 224 Text feature [involved] present in test data point [True]
# 225 Text feature [interactions] present in test data point [True]
# 226 Text feature [pattern] present in test data point [True]
# 228 Text feature [also] present in test data point [True]
# 229 Text feature [4a] present in test data point [True]
# 230 Text feature [ii] present in test data point [True]
# 232 Text feature [expressed] present in test data point [True]
# 234 Text feature [mrna] present in test data point [True]
# 235 Text feature [common] present in test data point [True]
# 236 Text feature [mean] present in test data point [True]
# 237 Text feature [genetic] present in test data point [True]
# 240 Text feature [resulting] present in test data point [True]
# 241 Text feature [human] present in test data point [True]
# 244 Text feature [domain] present in test data point [True]
# 246 Text feature [36] present in test data point [True]
# 248 Text feature [next] present in test data point [True]
# 249 Text feature [nucleotide] present in test data point [True]
# 252 Text feature [manner] present in test data point [True]
# 253 Text feature [42] present in test data point [True]
# 256 Text feature [41] present in test data point [True]
# 261 Text feature [alterations] present in test data point [True]
# 262 Text feature [established] present in test data point [True]
# 263 Text feature [average] present in test data point [True]
# 264 Text feature [locus] present in test data point [True]
# 265 Text feature [fold] present in test data point [True]
# 266 Text feature [important] present in test data point [True]
# 269 Text feature [allele] present in test data point [True]
# 270 Text feature [deletions] present in test data point [True]
# 272 Text feature [involving] present in test data point [True]
# 273 Text feature [blood] present in test data point [True]
# 274 Text feature [nras] present in test data point [True]
# 275 Text feature [defects] present in test data point [True]
# 276 Text feature [population] present in test data point [True]
# 280 Text feature [sample] present in test data point [True]
# 287 Text feature [normal] present in test data point [True]
# 290 Text feature [heterozygous] present in test data point [True]
# 291 Text feature [related] present in test data point [True]
# 292 Text feature [cbl] present in test data point [True]
# 293 Text feature [200] present in test data point [True]
# 295 Text feature [induced] present in test data point [True]
# 297 Text feature [small] present in test data point [True]
# 302 Text feature [transfected] present in test data point [True]
# 305 Text feature [expressing] present in test data point [True]
# 306 Text feature [different] present in test data point [True]
# 307 Text feature [16] present in test data point [True]
# 313 Text feature [expression] present in test data point [True]
# 314 Text feature [primary] present in test data point [True]
# 315 Text feature [absence] present in test data point [True]
# 320 Text feature [dominant] present in test data point [True]
# 324 Text feature [s3] present in test data point [True]
# 325 Text feature [strong] present in test data point [True]
# 327 Text feature [line] present in test data point [True]
# 335 Text feature [decreased] present in test data point [True]
# 338 Text feature [activated] present in test data point [True]
# 340 Text feature [2a] present in test data point [True]
# 341 Text feature [critical] present in test data point [True]
# 342 Text feature [site] present in test data point [True]
# 343 Text feature [mediated] present in test data point [True]
# 344 Text feature [four] present in test data point [True]
# 346 Text feature [cancer] present in test data point [True]
# 347 Text feature [31] present in test data point [True]
# 349 Text feature [go] present in test data point [True]
# 350 Text feature [cause] present in test data point [True]
# 355 Text feature [models] present in test data point [True]
# 357 Text feature [top] present in test data point [True]
# 358 Text feature [significant] present in test data point [True]
# 361 Text feature [ring] present in test data point [True]
# 362 Text feature [negative] present in test data point [True]
# 364 Text feature [comparison] present in test data point [True]
# 365 Text feature [induce] present in test data point [True]
# 366 Text feature [tumor] present in test data point [True]
# 368 Text feature [lower] present in test data point [True]
# 370 Text feature [primers] present in test data point [True]
# 372 Text feature [findings] present in test data point [True]
# 374 Text feature [46] present in test data point [True]
# 375 Text feature [activating] present in test data point [True]
# 376 Text feature [tet2] present in test data point [True]
# 377 Text feature [high] present in test data point [True]
# 383 Text feature [23] present in test data point [True]
# 387 Text feature [genes] present in test data point [True]
# 388 Text feature [mutation] present in test data point [True]
# 389 Text feature [respectively] present in test data point [True]
# 390 Text feature [occur] present in test data point [True]
# 391 Text feature [performed] present in test data point [True]
# 392 Text feature [number] present in test data point [True]
# 394 Text feature [interaction] present in test data point [True]
# 395 Text feature [partial] present in test data point [True]
# 396 Text feature [pathway] present in test data point [True]
# 399 Text feature [report] present in test data point [True]
# 402 Text feature [conditions] present in test data point [True]
# 404 Text feature [reported] present in test data point [True]
# 406 Text feature [identification] present in test data point [True]
# 407 Text feature [regulated] present in test data point [True]
# 408 Text feature [amino] present in test data point [True]
# 410 Text feature [01] present in test data point [True]
# 414 Text feature [germline] present in test data point [True]
# 417 Text feature [13] present in test data point [True]
# 422 Text feature [nature] present in test data point [True]
# 423 Text feature [database] present in test data point [True]
# 425 Text feature [effect] present in test data point [True]
# 430 Text feature [activation] present in test data point [True]
# 431 Text feature [inhibitor] present in test data point [True]
# 434 Text feature [measured] present in test data point [True]
# 435 Text feature [iii] present in test data point [True]
# 437 Text feature [1b] present in test data point [True]
# 438 Text feature [sequence] present in test data point [True]
# 439 Text feature [kd] present in test data point [True]
# 441 Text feature [evidence] present in test data point [True]
# 442 Text feature [previously] present in test data point [True]
# 443 Text feature [might] present in test data point [True]
# 444 Text feature [47] present in test data point [True]
# 446 Text feature [27] present in test data point [True]
# 447 Text feature [system] present in test data point [True]
# 448 Text feature [therapeutic] present in test data point [True]
# 450 Text feature [forms] present in test data point [True]
# 451 Text feature [hr] present in test data point [True]
# 453 Text feature [stable] present in test data point [True]
# 454 Text feature [indicates] present in test data point [True]
# 455 Text feature [growth] present in test data point [True]
# 458 Text feature [observation] present in test data point [True]
# 460 Text feature [transformation] present in test data point [True]
# 461 Text feature [org] present in test data point [True]
# 464 Text feature [located] present in test data point [True]
# 471 Text feature [highly] present in test data point [True]
# 473 Text feature [found] present in test data point [True]
# 474 Text feature [result] present in test data point [True]
# 475 Text feature [downstream] present in test data point [True]
# 476 Text feature [proteins] present in test data point [True]
# 478 Text feature [first] present in test data point [True]
# 481 Text feature [response] present in test data point [True]
# 482 Text feature [patient] present in test data point [True]
# 486 Text feature [50] present in test data point [True]
# 491 Text feature [met] present in test data point [True]
# 492 Text feature [oncogenic] present in test data point [True]
# 494 Text feature [95] present in test data point [True]
# 495 Text feature [rna] present in test data point [True]
# 497 Text feature [specimens] present in test data point [True]
# 498 Text feature [control] present in test data point [True]
# Out of the top  500  features  232 are present in query point

# %% [markdown]
# <h2>4.4. Linear Support Vector Machines</h2>

# %% [markdown]
# <h3>4.4.1. Hyper paramter tuning</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------



# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10 ** x for x in range(-5, 3)]
cv_log_error_array = []
for i in alpha:
    print("for C =", i)
#     clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
    clf = SGDClassifier( class_weight='balanced', alpha=i, penalty='l2', loss='hinge', random_state=42)
    clf.fit(train_x_onehotCoding, train_y)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(train_x_onehotCoding, train_y)
    sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
    cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
    print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

fig, ax = plt.subplots()
ax.plot(alpha, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[i],str(txt)), (alpha[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(cv_log_error_array)
# clf = SVC(C=i,kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(class_weight='balanced', alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for C = 1e-05
# Log Loss : 1.0723680704995986
# for C = 0.0001
# Log Loss : 1.0507580115191477
# for C = 0.001
# Log Loss : 1.1477591345575597
# for C = 0.01
# Log Loss : 1.2872108269038176
# for C = 0.1
# Log Loss : 1.2328337007094146
# for C = 1
# Log Loss : 1.6504664263205675
# for C = 10
# Log Loss : 1.7713781164724012
# for C = 100
# Log Loss : 1.7713768609202252
# For values of best alpha =  0.0001 The train log loss is: 0.8335889542721645
# For values of best alpha =  0.0001 The cross validation log loss is: 1.0507580115191477
# For values of best alpha =  0.0001 The test log loss is: 1.0735259555645746

# %% [markdown]
# <h3>4.4.2. Testing model with best hyper parameters</h3>

# %%
# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html

# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# clf = SVC(C=alpha[best_alpha],kernel='linear',probability=True, class_weight='balanced')
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42,class_weight='balanced')
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.0507580115191477
# Number of mis-classified points : 0.33270676691729323
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.3.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.3.3.1. For Correctly classified point</h4>

# %%
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='hinge', random_state=42)
clf.fit(train_x_onehotCoding,train_y)
test_point_index = 1
# test_point_index = 100
no_feature = 500
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-1*abs(clf.coef_))[predicted_cls-1][:,:no_feature]
print("-"*50)
get_impfeature_names(indices[0], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.868  0.0675 0.002  0.0061 0.0042 0.0312 0.0162 0.0039 0.0009]]
# Actual Class : 1
# --------------------------------------------------
# 0 Text feature [splice] present in test data point [True]
# 2 Text feature [determine] present in test data point [True]
# 3 Text feature [proliferation] present in test data point [True]
# 4 Text feature [confirmed] present in test data point [True]
# 8 Text feature [19] present in test data point [True]
# 10 Text feature [majority] present in test data point [True]
# 15 Text feature [functional] present in test data point [True]
# 16 Text feature [test] present in test data point [True]
# 20 Text feature [analyzed] present in test data point [True]
# 21 Text feature [receptor] present in test data point [True]
# 23 Text feature [il] present in test data point [True]
# 24 Text feature [pathogenic] present in test data point [True]
# 25 Text feature [binding] present in test data point [True]
# 30 Text feature [samples] present in test data point [True]
# 31 Text feature [nih] present in test data point [True]
# 32 Text feature [novel] present in test data point [True]
# 33 Text feature [selected] present in test data point [True]
# 34 Text feature [driven] present in test data point [True]
# 35 Text feature [antibodies] present in test data point [True]
# 36 Text feature [development] present in test data point [True]
# 38 Text feature [significance] present in test data point [True]
# 40 Text feature [cells] present in test data point [True]
# 43 Text feature [two] present in test data point [True]
# 47 Text feature [degradation] present in test data point [True]
# 48 Text feature [cellular] present in test data point [True]
# 50 Text feature [mechanism] present in test data point [True]
# 52 Text feature [together] present in test data point [True]
# 53 Text feature [diagnosis] present in test data point [True]
# 54 Text feature [suggest] present in test data point [True]
# 55 Text feature [regulatory] present in test data point [True]
# 61 Text feature [taken] present in test data point [True]
# 65 Text feature [generated] present in test data point [True]
# 66 Text feature [showed] present in test data point [True]
# 68 Text feature [mouse] present in test data point [True]
# 71 Text feature [resulted] present in test data point [True]
# 74 Text feature [factors] present in test data point [True]
# 76 Text feature [harboring] present in test data point [True]
# 77 Text feature [factor] present in test data point [True]
# 80 Text feature [family] present in test data point [True]
# 81 Text feature [effects] present in test data point [True]
# 84 Text feature [differences] present in test data point [True]
# 87 Text feature [cases] present in test data point [True]
# 95 Text feature [34] present in test data point [True]
# 96 Text feature [figure] present in test data point [True]
# 99 Text feature [pattern] present in test data point [True]
# 103 Text feature [domain] present in test data point [True]
# 105 Text feature [several] present in test data point [True]
# 106 Text feature [26] present in test data point [True]
# 107 Text feature [considered] present in test data point [True]
# 109 Text feature [transcriptional] present in test data point [True]
# 111 Text feature [represent] present in test data point [True]
# 112 Text feature [29] present in test data point [True]
# 115 Text feature [manner] present in test data point [True]
# 116 Text feature [detected] present in test data point [True]
# 118 Text feature [observed] present in test data point [True]
# 120 Text feature [suppression] present in test data point [True]
# 121 Text feature [growth] present in test data point [True]
# 122 Text feature [efficacy] present in test data point [True]
# 123 Text feature [four] present in test data point [True]
# 124 Text feature [single] present in test data point [True]
# 125 Text feature [lymphoma] present in test data point [True]
# 126 Text feature [key] present in test data point [True]
# 128 Text feature [available] present in test data point [True]
# 130 Text feature [expected] present in test data point [True]
# 132 Text feature [recently] present in test data point [True]
# 134 Text feature [investigated] present in test data point [True]
# 135 Text feature [based] present in test data point [True]
# 136 Text feature [expressed] present in test data point [True]
# 139 Text feature [analysis] present in test data point [True]
# 140 Text feature [primary] present in test data point [True]
# 141 Text feature [multiple] present in test data point [True]
# 142 Text feature [28] present in test data point [True]
# 143 Text feature [type] present in test data point [True]
# 146 Text feature [aml] present in test data point [True]
# 147 Text feature [average] present in test data point [True]
# 154 Text feature [resulting] present in test data point [True]
# 155 Text feature [lead] present in test data point [True]
# 156 Text feature [established] present in test data point [True]
# 157 Text feature [shown] present in test data point [True]
# 159 Text feature [mrna] present in test data point [True]
# 161 Text feature [consistent] present in test data point [True]
# 162 Text feature [reported] present in test data point [True]
# 163 Text feature [defects] present in test data point [True]
# 164 Text feature [locus] present in test data point [True]
# 174 Text feature [mean] present in test data point [True]
# 175 Text feature [2a] present in test data point [True]
# 176 Text feature [alleles] present in test data point [True]
# 177 Text feature [found] present in test data point [True]
# 179 Text feature [interactions] present in test data point [True]
# 181 Text feature [involving] present in test data point [True]
# 182 Text feature [ca] present in test data point [True]
# 183 Text feature [containing] present in test data point [True]
# 184 Text feature [clones] present in test data point [True]
# 185 Text feature [fold] present in test data point [True]
# 186 Text feature [reduced] present in test data point [True]
# 189 Text feature [next] present in test data point [True]
# 191 Text feature [nras] present in test data point [True]
# 194 Text feature [materials] present in test data point [True]
# 195 Text feature [located] present in test data point [True]
# 202 Text feature [chromosome] present in test data point [True]
# 205 Text feature [human] present in test data point [True]
# 206 Text feature [function] present in test data point [True]
# 208 Text feature [progression] present in test data point [True]
# 209 Text feature [complex] present in test data point [True]
# 219 Text feature [41] present in test data point [True]
# 224 Text feature [show] present in test data point [True]
# 225 Text feature [specimens] present in test data point [True]
# 227 Text feature [important] present in test data point [True]
# 228 Text feature [also] present in test data point [True]
# 230 Text feature [patients] present in test data point [True]
# 231 Text feature [known] present in test data point [True]
# 232 Text feature [site] present in test data point [True]
# 233 Text feature [phase] present in test data point [True]
# 236 Text feature [may] present in test data point [True]
# 240 Text feature [cause] present in test data point [True]
# 245 Text feature [features] present in test data point [True]
# 246 Text feature [top] present in test data point [True]
# 248 Text feature [line] present in test data point [True]
# 249 Text feature [previously] present in test data point [True]
# 259 Text feature [42] present in test data point [True]
# 260 Text feature [knockdown] present in test data point [True]
# 262 Text feature [activated] present in test data point [True]
# 265 Text feature [transfected] present in test data point [True]
# 267 Text feature [control] present in test data point [True]
# 268 Text feature [therapy] present in test data point [True]
# 269 Text feature [expression] present in test data point [True]
# 270 Text feature [nucleotide] present in test data point [True]
# 271 Text feature [alterations] present in test data point [True]
# 272 Text feature [performed] present in test data point [True]
# 273 Text feature [models] present in test data point [True]
# 275 Text feature [200] present in test data point [True]
# 276 Text feature [genetic] present in test data point [True]
# 277 Text feature [allele] present in test data point [True]
# 278 Text feature [response] present in test data point [True]
# 280 Text feature [studied] present in test data point [True]
# 281 Text feature [sequence] present in test data point [True]
# 283 Text feature [4a] present in test data point [True]
# 285 Text feature [tumors] present in test data point [True]
# 286 Text feature [observation] present in test data point [True]
# 287 Text feature [16] present in test data point [True]
# 288 Text feature [independent] present in test data point [True]
# 290 Text feature [normal] present in test data point [True]
# 291 Text feature [high] present in test data point [True]
# 295 Text feature [induced] present in test data point [True]
# 296 Text feature [partial] present in test data point [True]
# 298 Text feature [findings] present in test data point [True]
# 314 Text feature [heterozygous] present in test data point [True]
# 315 Text feature [population] present in test data point [True]
# 318 Text feature [methods] present in test data point [True]
# 319 Text feature [negative] present in test data point [True]
# 322 Text feature [absence] present in test data point [True]
# 323 Text feature [involved] present in test data point [True]
# 324 Text feature [recent] present in test data point [True]
# 325 Text feature [23] present in test data point [True]
# 328 Text feature [amino] present in test data point [True]
# 329 Text feature [three] present in test data point [True]
# 330 Text feature [activating] present in test data point [True]
# 331 Text feature [nature] present in test data point [True]
# 332 Text feature [mutation] present in test data point [True]
# 333 Text feature [activation] present in test data point [True]
# 337 Text feature [measured] present in test data point [True]
# 339 Text feature [part] present in test data point [True]
# 341 Text feature [months] present in test data point [True]
# 344 Text feature [essential] present in test data point [True]
# 346 Text feature [downstream] present in test data point [True]
# 347 Text feature [go] present in test data point [True]
# 349 Text feature [ii] present in test data point [True]
# 353 Text feature [dominant] present in test data point [True]
# 354 Text feature [genes] present in test data point [True]
# 356 Text feature [frequency] present in test data point [True]
# 357 Text feature [defined] present in test data point [True]
# 358 Text feature [target] present in test data point [True]
# 362 Text feature [rna] present in test data point [True]
# 367 Text feature [demonstrate] present in test data point [True]
# 368 Text feature [significant] present in test data point [True]
# 371 Text feature [comparison] present in test data point [True]
# 372 Text feature [defective] present in test data point [True]
# 374 Text feature [tumor] present in test data point [True]
# 375 Text feature [related] present in test data point [True]
# 377 Text feature [functions] present in test data point [True]
# 378 Text feature [org] present in test data point [True]
# 379 Text feature [age] present in test data point [True]
# 380 Text feature [conserved] present in test data point [True]
# 381 Text feature [s3] present in test data point [True]
# 384 Text feature [small] present in test data point [True]
# 386 Text feature [major] present in test data point [True]
# 388 Text feature [germline] present in test data point [True]
# 391 Text feature [35] present in test data point [True]
# 393 Text feature [however] present in test data point [True]
# 396 Text feature [mediated] present in test data point [True]
# 397 Text feature [set] present in test data point [True]
# 402 Text feature [iii] present in test data point [True]
# 405 Text feature [expressing] present in test data point [True]
# 406 Text feature [different] present in test data point [True]
# 407 Text feature [conditions] present in test data point [True]
# 409 Text feature [ring] present in test data point [True]
# 410 Text feature [decreased] present in test data point [True]
# 412 Text feature [altered] present in test data point [True]
# 418 Text feature [lower] present in test data point [True]
# 419 Text feature [risk] present in test data point [True]
# 421 Text feature [suggesting] present in test data point [True]
# 422 Text feature [36] present in test data point [True]
# 423 Text feature [sample] present in test data point [True]
# 425 Text feature [critical] present in test data point [True]
# 432 Text feature [05] present in test data point [True]
# 434 Text feature [occur] present in test data point [True]
# 436 Text feature [cdna] present in test data point [True]
# 439 Text feature [stable] present in test data point [True]
# 440 Text feature [leads] present in test data point [True]
# 443 Text feature [interaction] present in test data point [True]
# 449 Text feature [31] present in test data point [True]
# 452 Text feature [inhibitor] present in test data point [True]
# 454 Text feature [regulated] present in test data point [True]
# 456 Text feature [30] present in test data point [True]
# 457 Text feature [series] present in test data point [True]
# 460 Text feature [95] present in test data point [True]
# 463 Text feature [syndrome] present in test data point [True]
# 465 Text feature [therapeutic] present in test data point [True]
# 466 Text feature [given] present in test data point [True]
# 467 Text feature [met] present in test data point [True]
# 468 Text feature [reaction] present in test data point [True]
# 474 Text feature [deletions] present in test data point [True]
# 483 Text feature [mutated] present in test data point [True]
# 484 Text feature [50] present in test data point [True]
# 487 Text feature [40] present in test data point [True]
# 489 Text feature [subset] present in test data point [True]
# 490 Text feature [recurrent] present in test data point [True]
# 494 Text feature [et] present in test data point [True]
# Out of the top  500  features  228 are present in query point

# %% [markdown]
# <h2>4.5 Random Forest Classifier</h2>

# %% [markdown]
# <h3>4.5.1. Hyper paramter tuning (With One hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [100,200,500,1000,2000]
max_depth = [5, 10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_onehotCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_onehotCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_onehotCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 

'''fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/2)],max_depth[int(i%2)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_onehotCoding)
print('For values of best estimator = ', alpha[int(best_alpha/2)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.1869014460931373
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.1751538603402734
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.171766540114671
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.1699631173254972
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.1661316436213014
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.1736128673619242
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.1601820177226434
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.1760478266638557
# for n_estimators = 2000 and max depth =  5
# Log Loss : 1.1580935593477004
# for n_estimators = 2000 and max depth =  10
# Log Loss : 1.1765919095830584
# For values of best estimator =  2000 The train log loss is: 0.9225572929195821
# For values of best estimator =  2000 The cross validation log loss is: 1.1580935593477004
# For values of best estimator =  2000 The test log loss is: 1.1519798090666307

# %% [markdown]
# <h3>4.5.2. Testing model with best hyper parameters (One Hot Encoding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
predict_and_plot_confusion_matrix(train_x_onehotCoding, train_y,cv_x_onehotCoding,cv_y, clf)
# Out:
# Log loss : 1.1580935593477004
# Number of mis-classified points : 0.40037593984962405
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.3. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.3.1. Correctly Classified point</h4>

# %%
# test_point_index = 10
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/2)], criterion='gini', max_depth=max_depth[int(best_alpha%2)], random_state=42, n_jobs=-1)
clf.fit(train_x_onehotCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_onehotCoding, train_y)

test_point_index = 1
no_feature = 100
predicted_cls = sig_clf.predict(test_x_onehotCoding[test_point_index])
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_onehotCoding[test_point_index]),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
get_impfeature_names(indices[:no_feature], test_df['TEXT'].iloc[test_point_index],test_df['Gene'].iloc[test_point_index],test_df['Variation'].iloc[test_point_index], no_feature)
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.5365 0.0701 0.0134 0.1586 0.0464 0.0436 0.0722 0.0098 0.0494]]
# Actual Class : 1
# --------------------------------------------------
# 2 Text feature [tet2] present in test data point [True]
# 3 Text feature [36] present in test data point [True]
# 4 Text feature [35] present in test data point [True]
# 7 Text feature [37] present in test data point [True]
# 8 Text feature [specimens] present in test data point [True]
# 9 Text feature [observations] present in test data point [True]
# 11 Text feature [34] present in test data point [True]
# 14 Text feature [loop] present in test data point [True]
# 15 Text feature [taken] present in test data point [True]
# 17 Text feature [loss] present in test data point [True]
# 20 Text feature [analyzed] present in test data point [True]
# 21 Text feature [two] present in test data point [True]
# 22 Text feature [multiple] present in test data point [True]
# 23 Text feature [expression] present in test data point [True]
# 25 Text feature [involving] present in test data point [True]
# 26 Text feature [differentiation] present in test data point [True]
# 28 Text feature [expressing] present in test data point [True]
# 29 Text feature [results] present in test data point [True]
# 30 Text feature [mrna] present in test data point [True]
# 33 Text feature [considered] present in test data point [True]
# 35 Text feature [cells] present in test data point [True]
# 38 Text feature [antibody] present in test data point [True]
# 39 Text feature [46] present in test data point [True]
# 40 Text feature [biological] present in test data point [True]
# 41 Text feature [33] present in test data point [True]
# 42 Text feature [survival] present in test data point [True]
# 43 Text feature [sequencing] present in test data point [True]
# 45 Text feature [antibodies] present in test data point [True]
# 47 Text feature [included] present in test data point [True]
# 51 Text feature [followed] present in test data point [True]
# 52 Text feature [analysis] present in test data point [True]
# 55 Text feature [decreased] present in test data point [True]
# 56 Text feature [nih] present in test data point [True]
# 58 Text feature [demonstrated] present in test data point [True]
# 59 Text feature [transfected] present in test data point [True]
# 60 Text feature [malignant] present in test data point [True]
# 61 Text feature [suppression] present in test data point [True]
# 66 Text feature [genomic] present in test data point [True]
# 68 Text feature [strong] present in test data point [True]
# 72 Text feature [mutation] present in test data point [True]
# 73 Text feature [nature] present in test data point [True]
# 75 Text feature [conditions] present in test data point [True]
# 76 Text feature [known] present in test data point [True]
# 80 Text feature [mutated] present in test data point [True]
# 82 Text feature [rather] present in test data point [True]
# 84 Text feature [due] present in test data point [True]
# 88 Text feature [leukemia] present in test data point [True]
# 92 Text feature [demonstrate] present in test data point [True]
# 96 Text feature [methods] present in test data point [True]
# 99 Text feature [patient] present in test data point [True]
# Out of the top  100  features  50 are present in query point

# %% [markdown]
# <h3>4.5.3. Hyper paramter tuning (With Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


# find more about CalibratedClassifierCV here at http://scikit-learn.org/stable/modules/generated/sklearn.calibration.CalibratedClassifierCV.html
# ----------------------------
# default paramters
# sklearn.calibration.CalibratedClassifierCV(base_estimator=None, method=’sigmoid’, cv=3)
#
# some of the methods of CalibratedClassifierCV()
# fit(X, y[, sample_weight])	Fit the calibrated model
# get_params([deep])	Get parameters for this estimator.
# predict(X)	Predict the target of new samples.
# predict_proba(X)	Posterior probabilities of classification
#-------------------------------------
# video link:
#-------------------------------------

alpha = [10,50,100,200,500,1000]
max_depth = [2,3,5,10]
cv_log_error_array = []
for i in alpha:
    for j in max_depth:
        print("for n_estimators =", i,"and max depth = ", j)
        clf = RandomForestClassifier(n_estimators=i, criterion='gini', max_depth=j, random_state=42, n_jobs=-1)
        clf.fit(train_x_responseCoding, train_y)
        sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
        sig_clf.fit(train_x_responseCoding, train_y)
        sig_clf_probs = sig_clf.predict_proba(cv_x_responseCoding)
        cv_log_error_array.append(log_loss(cv_y, sig_clf_probs, labels=clf.classes_, eps=1e-15))
        print("Log Loss :",log_loss(cv_y, sig_clf_probs)) 
'''
fig, ax = plt.subplots()
features = np.dot(np.array(alpha)[:,None],np.array(max_depth)[None]).ravel()
ax.plot(features, cv_log_error_array,c='g')
for i, txt in enumerate(np.round(cv_log_error_array,3)):
    ax.annotate((alpha[int(i/4)],max_depth[int(i%4)],str(txt)), (features[i],cv_log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()
'''

best_alpha = np.argmin(cv_log_error_array)
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)

predict_y = sig_clf.predict_proba(train_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(cv_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The cross validation log loss is:",log_loss(y_cv, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(test_x_responseCoding)
print('For values of best alpha = ', alpha[int(best_alpha/4)], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# for n_estimators = 10 and max depth =  2
# Log Loss : 1.9225781441021048
# for n_estimators = 10 and max depth =  3
# Log Loss : 1.8512592565045463
# for n_estimators = 10 and max depth =  5
# Log Loss : 1.8761650317753085
# for n_estimators = 10 and max depth =  10
# Log Loss : 1.592636355795102
# for n_estimators = 50 and max depth =  2
# Log Loss : 1.6354483935561062
# for n_estimators = 50 and max depth =  3
# Log Loss : 1.47781897437219
# for n_estimators = 50 and max depth =  5
# Log Loss : 1.234553356926856
# for n_estimators = 50 and max depth =  10
# Log Loss : 1.6093654793380814
# for n_estimators = 100 and max depth =  2
# Log Loss : 1.5033596746913633
# for n_estimators = 100 and max depth =  3
# Log Loss : 1.356371813495302
# for n_estimators = 100 and max depth =  5
# Log Loss : 1.1590321501432157
# for n_estimators = 100 and max depth =  10
# Log Loss : 1.6618956651680905
# for n_estimators = 200 and max depth =  2
# Log Loss : 1.5364327971394616
# for n_estimators = 200 and max depth =  3
# Log Loss : 1.3827107298560775
# for n_estimators = 200 and max depth =  5
# Log Loss : 1.252643900479426
# for n_estimators = 200 and max depth =  10
# Log Loss : 1.657548802209118
# for n_estimators = 500 and max depth =  2
# Log Loss : 1.488519302246698
# for n_estimators = 500 and max depth =  3
# Log Loss : 1.373635990971768
# for n_estimators = 500 and max depth =  5
# Log Loss : 1.2239690018702833
# for n_estimators = 500 and max depth =  10
# Log Loss : 1.5945564436405766
# for n_estimators = 1000 and max depth =  2
# Log Loss : 1.5717044333049845
# for n_estimators = 1000 and max depth =  3
# Log Loss : 1.4193219320597756
# for n_estimators = 1000 and max depth =  5
# Log Loss : 1.2598541596403847
# for n_estimators = 1000 and max depth =  10
# Log Loss : 1.6293489617751866
# For values of best alpha =  100 The train log loss is: 0.06067998174000714
# For values of best alpha =  100 The cross validation log loss is: 1.1590321501432157
# For values of best alpha =  100 The test log loss is: 1.1646526196006626

# %% [markdown]
# <h3>4.5.4. Testing model with best hyper parameters (Response Coding)</h3>

# %%
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------

clf = RandomForestClassifier(max_depth=max_depth[int(best_alpha%4)], n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_features='auto',random_state=42)
predict_and_plot_confusion_matrix(train_x_responseCoding, train_y,cv_x_responseCoding,cv_y, clf)
# Out:
# Log loss : 1.1590321501432157
# Number of mis-classified points : 0.40789473684210525
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.5.5. Feature Importance</h3>

# %% [markdown]
# <h4>4.5.5.1. Correctly Classified point</h4>

# %%
clf = RandomForestClassifier(n_estimators=alpha[int(best_alpha/4)], criterion='gini', max_depth=max_depth[int(best_alpha%4)], random_state=42, n_jobs=-1)
clf.fit(train_x_responseCoding, train_y)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(train_x_responseCoding, train_y)


test_point_index = 1
no_feature = 27
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 1
# Predicted Class Probabilities: [[0.9501 0.0053 0.0024 0.0061 0.0025 0.0167 0.0018 0.0087 0.0065]]
# Actual Class : 1
# --------------------------------------------------
# Text is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h4>4.5.5.2. Incorrectly Classified point</h4>

# %%
test_point_index = 100
predicted_cls = sig_clf.predict(test_x_responseCoding[test_point_index].reshape(1,-1))
print("Predicted Class :", predicted_cls[0])
print("Predicted Class Probabilities:", np.round(sig_clf.predict_proba(test_x_responseCoding[test_point_index].reshape(1,-1)),4))
print("Actual Class :", test_y[test_point_index])
indices = np.argsort(-clf.feature_importances_)
print("-"*50)
for i in indices:
    if i<9:
        print("Gene is important feature")
    elif i<18:
        print("Variation is important feature")
    else:
        print("Text is important feature")
# Out:
# Predicted Class : 2
# Predicted Class Probabilities: [[0.0102 0.5236 0.0589 0.015  0.0298 0.0277 0.2939 0.0276 0.0134]]
# Actual Class : 7
# --------------------------------------------------
# Text is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Text is important feature
# Gene is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Text is important feature
# Text is important feature
# Text is important feature
# Variation is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature
# Gene is important feature

# %% [markdown]
# <h2>4.7 Stack the models </h2>

# %% [markdown]
# <h3>4.7.1 testing with hyper parameter tuning</h3>

# %%
# read more about SGDClassifier() at http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDClassifier.html
# ------------------------------
# default parameters
# SGDClassifier(loss=’hinge’, penalty=’l2’, alpha=0.0001, l1_ratio=0.15, fit_intercept=True, max_iter=None, tol=None, 
# shuffle=True, verbose=0, epsilon=0.1, n_jobs=1, random_state=None, learning_rate=’optimal’, eta0=0.0, power_t=0.5, 
# class_weight=None, warm_start=False, average=False, n_iter=None)

# some of methods
# fit(X, y[, coef_init, intercept_init, …])	Fit linear model with Stochastic Gradient Descent.
# predict(X)	Predict class labels for samples in X.

#-------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/geometric-intuition-1/
#------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# --------------------------------
# default parameters 
# SVC(C=1.0, kernel=’rbf’, degree=3, gamma=’auto’, coef0=0.0, shrinking=True, probability=False, tol=0.001, 
# cache_size=200, class_weight=None, verbose=False, max_iter=-1, decision_function_shape=’ovr’, random_state=None)

# Some of methods of SVM()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/mathematical-derivation-copy-8/
# --------------------------------


# read more about support vector machines with linear kernals here http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html
# --------------------------------
# default parameters 
# sklearn.ensemble.RandomForestClassifier(n_estimators=10, criterion=’gini’, max_depth=None, min_samples_split=2, 
# min_samples_leaf=1, min_weight_fraction_leaf=0.0, max_features=’auto’, max_leaf_nodes=None, min_impurity_decrease=0.0, 
# min_impurity_split=None, bootstrap=True, oob_score=False, n_jobs=1, random_state=None, verbose=0, warm_start=False, 
# class_weight=None)

# Some of methods of RandomForestClassifier()
# fit(X, y, [sample_weight])	Fit the SVM model according to the given training data.
# predict(X)	Perform classification on samples in X.
# predict_proba (X)	Perform classification on samples in X.

# some of attributes of  RandomForestClassifier()
# feature_importances_ : array of shape = [n_features]
# The feature importances (the higher, the more important the feature).

# --------------------------------
# video link: https://www.appliedaicourse.com/course/applied-ai-course-online/lessons/random-forest-and-their-construction-2/
# --------------------------------


clf1 = SGDClassifier(alpha=0.001, penalty='l2', loss='log', class_weight='balanced', random_state=0)
clf1.fit(train_x_onehotCoding, train_y)
sig_clf1 = CalibratedClassifierCV(clf1, method="sigmoid")

clf2 = SGDClassifier(alpha=1, penalty='l2', loss='hinge', class_weight='balanced', random_state=0)
clf2.fit(train_x_onehotCoding, train_y)
sig_clf2 = CalibratedClassifierCV(clf2, method="sigmoid")


clf3 = MultinomialNB(alpha=0.001)
clf3.fit(train_x_onehotCoding, train_y)
sig_clf3 = CalibratedClassifierCV(clf3, method="sigmoid")

sig_clf1.fit(train_x_onehotCoding, train_y)
print("Logistic Regression :  Log Loss: %0.2f" % (log_loss(cv_y, sig_clf1.predict_proba(cv_x_onehotCoding))))
sig_clf2.fit(train_x_onehotCoding, train_y)
print("Support vector machines : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf2.predict_proba(cv_x_onehotCoding))))
sig_clf3.fit(train_x_onehotCoding, train_y)
print("Naive Bayes : Log Loss: %0.2f" % (log_loss(cv_y, sig_clf3.predict_proba(cv_x_onehotCoding))))
print("-"*50)
alpha = [0.0001,0.001,0.01,0.1,1,10] 
best_alpha = 999
for i in alpha:
    lr = LogisticRegression(C=i)
    sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
    sclf.fit(train_x_onehotCoding, train_y)
    print("Stacking Classifer : for the value of alpha: %f Log Loss: %0.3f" % (i, log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))))
    log_error =log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
    if best_alpha > log_error:
        best_alpha = log_error
# Out:
# Logistic Regression :  Log Loss: 1.06
# Support vector machines : Log Loss: 1.65
# Naive Bayes : Log Loss: 1.15
# --------------------------------------------------
# Stacking Classifer : for the value of alpha: 0.000100 Log Loss: 1.821
# Stacking Classifer : for the value of alpha: 0.001000 Log Loss: 1.747
# Stacking Classifer : for the value of alpha: 0.010000 Log Loss: 1.425
# Stacking Classifer : for the value of alpha: 0.100000 Log Loss: 1.127
# Stacking Classifer : for the value of alpha: 1.000000 Log Loss: 1.034
# Stacking Classifer : for the value of alpha: 10.000000 Log Loss: 1.036

# %% [markdown]
# <h3>4.7.2 testing the model with the best hyper parameters</h3>

# %%
lr = LogisticRegression(C=0.1)
sclf = StackingClassifier(classifiers=[sig_clf1, sig_clf2, sig_clf3], meta_classifier=lr, use_probas=True)
sclf.fit(train_x_onehotCoding, train_y)

log_error = log_loss(train_y, sclf.predict_proba(train_x_onehotCoding))
print("Log loss (train) on the stacking classifier :",log_error)

log_error = log_loss(cv_y, sclf.predict_proba(cv_x_onehotCoding))
print("Log loss (CV) on the stacking classifier :",log_error)

log_error = log_loss(test_y, sclf.predict_proba(test_x_onehotCoding))
print("Log loss (test) on the stacking classifier :",log_error)

print("Number of missclassified point :", np.count_nonzero((sclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=sclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the stacking classifier : 1.1330429767264691
# Log loss (CV) on the stacking classifier : 1.127401393909854
# Log loss (test) on the stacking classifier : 1.1789777058390891
# Number of missclassified point : 0.3969924812030075
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# <h3>4.7.3 Maximum Voting classifier </h3>

# %%
#Refer:http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html
from sklearn.ensemble import VotingClassifier
vclf = VotingClassifier(estimators=[('lr', sig_clf1), ('svc', sig_clf2), ('rf', sig_clf3)], voting='soft')
vclf.fit(train_x_onehotCoding, train_y)
print("Log loss (train) on the VotingClassifier :", log_loss(train_y, vclf.predict_proba(train_x_onehotCoding)))
print("Log loss (CV) on the VotingClassifier :", log_loss(cv_y, vclf.predict_proba(cv_x_onehotCoding)))
print("Log loss (test) on the VotingClassifier :", log_loss(test_y, vclf.predict_proba(test_x_onehotCoding)))
print("Number of missclassified point :", np.count_nonzero((vclf.predict(test_x_onehotCoding)- test_y))/test_y.shape[0])
plot_confusion_matrix(test_y=test_y, predict_y=vclf.predict(test_x_onehotCoding))
# Out:
# Log loss (train) on the VotingClassifier : 1.1806819345581487
# Log loss (CV) on the VotingClassifier : 1.1837481784849364
# Log loss (test) on the VotingClassifier : 1.222824982964396
# Number of missclassified point : 0.4075187969924812
# -------------------- Confusion matrix --------------------
# -------------------- Precision matrix (Columm Sum=1) --------------------
# -------------------- Recall matrix (Row sum=1) --------------------

# %% [markdown]
# ###  We can observe that for Logistic Regression with Feature Engineering, the log-loss of CV data = 0.98 (less than 1) and the log-loss of test data = 1.01 (approximately equal to 1)
